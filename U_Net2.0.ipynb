# %% [markdown]
# <a href="https://colab.research.google.com/github/jhon-aparicio/semanticSegmentation/blob/main/U_Net2.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###PYTORCH CON U-NET 
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import torch
from torch import nn, optim
from torch.nn import functional as F
from torchvision import transforms as T
from torch.utils.data import DataLoader, Dataset, random_split
#
import PIL
from PIL import Image
#
# !pip install jupyterthemes
from jupyterthemes import jtplot
jtplot.style()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jupyterthemes in /usr/local/lib/python3.9/dist-packages (0.20.0)
# Requirement already satisfied: matplotlib>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from jupyterthemes) (3.5.3)
# Requirement already satisfied: ipython>=5.4.1 in /usr/local/lib/python3.9/dist-packages (from jupyterthemes) (7.9.0)
# Requirement already satisfied: lesscpy>=0.11.2 in /usr/local/lib/python3.9/dist-packages (from jupyterthemes) (0.15.1)
# Requirement already satisfied: notebook>=5.6.0 in /usr/local/lib/python3.9/dist-packages (from jupyterthemes) (6.3.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.9/dist-packages (from jupyterthemes) (5.2.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (2.0.10)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (0.18.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (2.6.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (5.7.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (57.4.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=5.4.1->jupyterthemes) (4.8.0)
# Requirement already satisfied: ply in /usr/local/lib/python3.9/dist-packages (from lesscpy>=0.11.2->jupyterthemes) (3.11)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (1.22.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (4.39.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=1.4.3->jupyterthemes) (1.4.4)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (21.3.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (23.2.1)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (0.17.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (3.1.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (5.7.3)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (5.3.4)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (0.16.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (6.1.12)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (6.2)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook>=5.6.0->jupyterthemes) (6.5.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core->jupyterthemes) (3.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=5.4.1->jupyterthemes) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.4.1->jupyterthemes) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5.4.1->jupyterthemes) (0.2.6)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.9/dist-packages (from terminado>=0.8.3->notebook>=5.6.0->jupyterthemes) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=5.6.0->jupyterthemes) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->notebook>=5.6.0->jupyterthemes) (2.1.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (4.6.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.7.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.2.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (4.9.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=5.6.0->jupyterthemes) (6.0.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=5.6.0->jupyterthemes) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=5.6.0->jupyterthemes) (22.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (1.15.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook>=5.6.0->jupyterthemes) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.6.0->jupyterthemes) (2.21)

# %%
# !git clone https://github.com/jhon-aparicio/semanticSegmentation.git
# Out:
# Cloning into 'semanticSegmentation'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 131 (delta 1), reused 131 (delta 1), pack-reused 0
# Receiving objects: 100% (131/131), 857.50 KiB | 21.99 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
PATH = '/content/semanticSegmentation/dataset/persona/'
TRAIN_PATH = '/content/semanticSegmentation/dataset/persona/train2/'
TRAIN_MASKS_PATH = '/content/semanticSegmentation/dataset/persona/segmentadas/'
TEST_PATH = '/content/semanticSegmentation/dataset/persona/val2/'
TEST2_PATH = '/content/semanticSegmentation/dataset/persona/val/'

# %%
class Person_Dataset(Dataset):
    def __init__(self, data, masks=None, img_transforms=None, mask_transforms=None):
        '''
        data - train data path
        masks - train masks path
        '''
        self.train_data = data
        self.train_masks = masks
        
        self.img_transforms = img_transforms
        self.mask_transforms = mask_transforms
        
        self.images = sorted(os.listdir(self.train_data))
        self.masks = sorted(os.listdir(self.train_masks))
        
    def __len__(self):
        if self.train_masks is not None:
            assert len(self.images)==len(self.masks), 'not the same number of images and masks'
        return len(self.images)
        
    def __getitem__(self, idx):
        image_name = os.path.join(self.train_data, self.images[idx])
        img = Image.open(image_name)
        trans = T.ToTensor()
        if self.img_transforms is not None:
            img = self.img_transforms(img)
        else:
            img =trans(img)
            img = torch.narrow(img, 1, 0, 3)
        
        if self.train_masks is not None:
            mask_name = os.path.join(self.train_masks, self.masks[idx])
            mask = Image.open(mask_name)
            if self.mask_transforms is not None:
                mask = self.mask_transforms(mask)
            else:
                mask = trans(mask)
            
            mask_max = mask.max().item()
            mask /= mask_max
        else:
            return img 

        return img, mask

# %%
transform_data = T.Compose([
                T.Resize([224, 224]),
                T.ToTensor()] )

# %%
full_dataset = Person_Dataset(TRAIN_PATH,
                           TRAIN_MASKS_PATH,
                           img_transforms=transform_data,
                           mask_transforms=transform_data)

# %%
BATCH_SIZE = 4
TRAIN_SIZE = int(len(full_dataset)*0.8)
VAL_SIZE = len(full_dataset) - TRAIN_SIZE

print(TRAIN_SIZE, VAL_SIZE)
# Out:
# 41 11

# %%
train_dataset, val_dataset = random_split(full_dataset, [TRAIN_SIZE, VAL_SIZE])
print(len(train_dataset), len(val_dataset))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
for batch_idx, (inputs, targets) in enumerate(train_loader):
    print(f'Batch {batch_idx}: inputs={inputs.shape}, targets={targets.shape}')

val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# 41 11
# Batch 0: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 1: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 2: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 3: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 4: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 5: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 6: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 7: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 8: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 9: inputs=torch.Size([4, 4, 224, 224]), targets=torch.Size([4, 1, 224, 224])
# Batch 10: inputs=torch.Size([1, 4, 224, 224]), targets=torch.Size([1, 1, 224, 224])

# %%
imgs, masks = next(iter(train_loader))
print(imgs.shape, masks.shape)
#imgs = torch.narrow(imgs, 1, 0, 3)
#print(imgs.shape)
for i, (x, y) in enumerate(train_loader):
    x = torch.narrow(x, 1, 0, 3)
    print(i, x.shape, y.shape)
    if i==9: break
# Out:
# torch.Size([4, 4, 224, 224]) torch.Size([4, 1, 224, 224])
# 0 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 1 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 2 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 3 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 4 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 5 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 6 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 7 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 8 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])
# 9 torch.Size([4, 3, 224, 224]) torch.Size([4, 1, 224, 224])

# %%
imgs, masks = next(iter(train_loader))
def plot_mini_batch(imgs, masks):
    plt.figure(figsize=(20,10))
    for i in range(BATCH_SIZE):
        plt.subplot(4, 8, i+1)
        img=imgs[i,...].permute(1,2,0).numpy()
        mask = masks[i, ...].permute(1,2,0).numpy()
        plt.imshow(img)
        plt.imshow(mask, alpha=0.5)
        
        plt.axis('Off')
    plt.tight_layout()
    plt.show()

plot_mini_batch(imgs, masks)

# %%
def accuracy(model, loader):
    correct = 0
    intersection = 0
    denom = 0
    union = 0
    total = 0
    cost = 0.
    model = model.to(device=device)
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype = torch.float32)
            x = torch.narrow(x, 1, 0, 3)
            y = y.to(device=device, dtype = torch.long).squeeze(1)
            scores = model(x)
            cost += (F.cross_entropy(scores, y)).item()
            # standard accuracy not optimal
            preds = torch.argmax(scores, dim=1)
            correct += (preds == y).sum()
            total += torch.numel(preds)
            #dice coefficient
            intersection += (preds*y).sum()
            denom += (preds + y).sum()
            dice = 2*intersection/(denom + 1e-8)
            #intersection over union
            union += (preds + y - preds*y).sum()
            iou = (intersection)/(union + 1e-8)
            
        return cost/len(loader), float(correct)/total, dice, iou

# %%
def find_lr(model, optimiser, start_val = 1e-6, end_val = 1, beta = 0.99, loader = train_loader):
    n = len(loader) - 1
    factor = (end_val / start_val)**(1/n)
    lr = start_val
    optimiser.param_groups[0]['lr'] = lr #this allows you to update the learning rate
    avg_loss, loss, acc = 0., 0., 0.
    lowest_loss = 0.
    batch_num = 0
    losses = []
    log_lrs = []
    accuracies = []
    model = model.to(device=device)
    for i, (x, y) in enumerate(loader, start=1):
        x = x.to(device = device, dtype = torch.float32)
        x = torch.narrow(x, 1, 0, 3)
        y = y.to(device = device, dtype = torch.long).squeeze(1)
        optimiser.zero_grad()
        scores = model(x)
        cost = F.cross_entropy(input=scores, target=y)
        loss = beta*loss + (1-beta)*cost.item()
        avg_loss = loss/(1 - beta**i)
        
        preds = torch.argmax(scores, dim=1)
        acc_ = (preds == y).sum()/torch.numel(scores)
        if i > 1 and avg_loss > 4 * lowest_loss:
            print(f'from here{i, cost.item()}')
            return log_lrs, losses, accuracies
        if avg_loss < lowest_loss or i == 1:
            lowest_loss = avg_loss

        accuracies.append(acc_.item())
        losses.append(avg_loss)
        log_lrs.append(lr)
        #step
        cost.backward()
        optimiser.step()
        #update lr
        print(f'cost:{cost.item():.4f}, lr: {lr:.4f}, acc: {acc_.item():.4f}')
        lr *= factor
        optimiser.param_groups[0]['lr'] = lr
        
    return log_lrs, losses, accuracies

# %%
def evaluate(model, loader):
    model.eval()
    model.to(device=device)
    with torch.no_grad():
        true_positives = 0
        false_positives = 0
        false_negatives = 0
        total = 0
        cost = 0
        for x, y in loader:
            x = x.to(device=device, dtype=torch.float32)
            x = torch.narrow(x, 1, 0, 3)
            y = y.to(device=device, dtype=torch.long).squeeze(1)
            scores = model(x)
            cost += (F.cross_entropy(scores, y)).item()
            preds = torch.argmax(scores, dim=1)
            true_positives += ((preds == 1) & (y == 1)).sum().item()
            false_positives += ((preds == 1) & (y == 0)).sum().item()
            false_negatives += ((preds == 0) & (y == 1)).sum().item()
            total += torch.numel(preds)
        accuracy = true_positives / total
        recall = true_positives / (true_positives + false_negatives)
        precision = true_positives / (true_positives + false_positives)
        if (precision + recall) ==0:
            f1_score = 0
        else:
            f1_score = 2 * (precision * recall) / (precision + recall)
        true_negatives = total - true_positives - false_positives - false_negatives
        confusion_matrix = [[true_positives, false_positives], [false_negatives, true_negatives]]
        print("Confusion Matrix:")
        print(confusion_matrix)
        return cost / len(loader), accuracy, recall, precision, f1_score, confusion_matrix

# %%
import torch
from sklearn.metrics import confusion_matrix
def lift(model, loader):
    thresholds = torch.arange(0, 1.01, 0.01)
    tprs = []
    fprs = []
    for threshold in thresholds:
        true_positives = 0
        false_positives = 0
        false_negatives = 0
        true_negatives = 0
        total = 0
        for x, y in loader:
            x = x.to(device=device, dtype=torch.float32)
            x = torch.narrow(x, 1, 0, 3)
            y = y.to(device=device, dtype=torch.long).squeeze(1)
            scores = model(x)
            preds = torch.where(scores[:, 1] > threshold, torch.tensor(1).to(device=device), torch.tensor(0).to(device=device))
            true_positives += ((preds == 1) & (y == 1)).sum().item()
            false_positives += ((preds == 1) & (y == 0)).sum().item()
            false_negatives += ((preds == 0) & (y == 1)).sum().item()
            true_negatives += ((preds == 0) & (y == 0)).sum().item()
            total += torch.numel(preds)
        tpr = true_positives / (true_positives + false_negatives)
        fpr = false_positives / (false_positives + true_negatives)
        tprs.append(tpr)
        fprs.append(fpr)
    return fprs, tprs

# %%
def train(model, optimiser, scheduler = None, epochs = 5000, store_every = 25):
    model = model.to(device=device)
    for epoch in range(epochs):
        train_correct_num = 0
        train_total = 0
        train_cost_acum = 0.
        for mb, (x, y) in enumerate(train_loader, start=1):
            model.train()
            x = x.to(device=device, dtype=torch.float32)
            x = torch.narrow(x, 1, 0, 3)
            y = y.to(device=device, dtype=torch.long).squeeze(1)
            scores = model(x)
            cost = F.cross_entropy(input=scores, target=y)
            optimiser.zero_grad()
            cost.backward()
            optimiser.step()
            
            if scheduler: 
                scheduler.step()
                
            train_predictions = torch.argmax(scores, dim=1)
            train_correct_num += (train_predictions == y).sum()
            train_total += torch.numel(train_predictions)
            train_cost_acum += cost.item()
            if mb%store_every == 0:
                val_cost, val_acc, dice, iou = accuracy(model, val_loader)
                train_acc = float(train_correct_num)/train_total
                train_cost_every = float(train_cost_acum)/mb
                loss, accuracy2, recall, precision, f1_score, confusion_matrix = evaluate(model, val_loader)
                print(f'epoch: {epoch}, mb: {mb}, train cost: {train_cost_every:.4f}, val cost: {val_cost:.4f},'
                      f'train acc: {train_acc:.4f}, val acc: {val_acc:.4f},'
                      f'dice: {dice}, iou: {iou}')
            else:
                val_cost, val_acc, dice, iou = accuracy(model, val_loader)
                train_acc = float(train_correct_num)/train_total
                train_cost_every = float(train_cost_acum)/mb
                print(f'epoch: {epoch}, mb: {mb}, train cost: {train_cost_every:.4f}, val cost: {val_cost:.4f},'
                      f'train acc: {train_acc:.4f}, val acc: {val_acc:.4f},'
                      f'dice: {dice}, iou: {iou}')

# %%
class Conv_3_k(nn.Module):
    def __init__(self, channels_in, channels_out):
        super().__init__()
        self.conv1 = nn.Conv2d(channels_in, channels_out, kernel_size=3, stride=1, padding=1)
    def forward(self, x):
        return self.conv1(x)

# %%
class Double_Conv(nn.Module):
    '''
    Double convolution block for U-Net
    '''
    def __init__(self, channels_in, channels_out):
        super().__init__()
        self.double_conv = nn.Sequential(
                           Conv_3_k(channels_in, channels_out),
                           nn.BatchNorm2d(channels_out),
                           nn.ReLU(),
            
                           Conv_3_k(channels_out, channels_out),
                           nn.BatchNorm2d(channels_out),
                           nn.ReLU(),
                            )
    def forward(self, x):
        return self.double_conv(x)
    
class Down_Conv(nn.Module):
    '''
    Down convolution part
    '''
    def __init__(self, channels_in, channels_out):
        super().__init__()
        self.encoder = nn.Sequential(
                        nn.MaxPool2d(2,2),
                        Double_Conv(channels_in, channels_out)
                        )
    def forward(self, x):
        return self.encoder(x)
    
class Up_Conv(nn.Module):
    '''
    Up convolution part
    '''
    def __init__(self,channels_in, channels_out):
        super().__init__()
        self.upsample_layer = nn.Sequential(
                        nn.Upsample(scale_factor=2, mode='bicubic'),
                        nn.Conv2d(channels_in, channels_in//2, kernel_size=1, stride=1)
                        )
        self.decoder = Double_Conv(channels_in, channels_out)
    
    def forward(self, x1, x2):
        '''
        x1 - upsampled volume
        x2 - volume from down sample to concatenate
        '''
        x1 = self.upsample_layer(x1)
        x = torch.cat([x2, x1],dim=1)
        return self.decoder(x)
    
class UNET(nn.Module):
    '''
    UNET model
    '''
    def __init__(self, channels_in, channels, num_classes):
        super().__init__()
        self.first_conv = Double_Conv(channels_in, channels) #64, 224, 224
        self.down_conv1 = Down_Conv(channels, 2*channels) # 128, 112, 112
        self.down_conv2 = Down_Conv(2*channels, 4*channels) # 256, 56, 56
        self.down_conv3 = Down_Conv(4*channels, 8*channels) # 512, 28, 28
        
        self.middle_conv = Down_Conv(8*channels, 16*channels) # 1024, 14, 14 
        
        self.up_conv1 = Up_Conv(16*channels, 8*channels)
        self.up_conv2 = Up_Conv(8*channels, 4*channels)
        self.up_conv3 = Up_Conv(4*channels, 2*channels)
        self.up_conv4 = Up_Conv(2*channels, channels)
        
        self.last_conv = nn.Conv2d(channels, num_classes, kernel_size=1, stride=1)
        
    def forward(self, x):
        x1 = self.first_conv(x)
        x2 = self.down_conv1(x1)
        x3 = self.down_conv2(x2)
        x4 = self.down_conv3(x3)
        
        x5 = self.middle_conv(x4)
        
        u1 = self.up_conv1(x5, x4)
        u2 = self.up_conv2(u1, x3)
        u3 = self.up_conv3(u2, x2)
        u4 = self.up_conv4(u3, x1)
        
        return self.last_conv(u4)

# %%
torch.manual_seed(42)
model = UNET(3, 4, 2)
optimiser_unet = torch.optim.SGD(model.parameters(),
                                 lr=0.01, momentum=0.95,
                                 weight_decay=1e-4)

lg_lr, losses, accuracies = find_lr(model, optimiser_unet, start_val=1e-6, end_val=10)
# Out:
# cost:0.8915, lr: 0.0000, acc: 0.0707
# cost:0.9016, lr: 0.0000, acc: 0.0629
# cost:0.8949, lr: 0.0000, acc: 0.0676
# cost:0.8977, lr: 0.0001, acc: 0.0644
# cost:0.8916, lr: 0.0006, acc: 0.0757
# cost:0.8878, lr: 0.0032, acc: 0.0726
# cost:0.8432, lr: 0.0158, acc: 0.1151
# cost:0.7160, lr: 0.0794, acc: 0.1883
# cost:0.3057, lr: 0.3981, acc: 0.4967
# cost:0.0373, lr: 1.9953, acc: 0.4977
# cost:0.3549, lr: 10.0000, acc: 0.4971

# %%
# plot loss vs learning rate
f1, ax1 = plt.subplots(figsize=(20,10))
ax1.plot(lg_lr, losses)
ax1.set_xscale('log')
plt.show()

# %%
torch.manual_seed(42)
model = UNET(3, 4, 2)
epochs = 750
optimiser_unet = torch.optim.SGD(model.parameters(),
                                 lr=0.01, momentum=0.95,
                                 weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.OneCycleLR(optimiser_unet, 
                                                max_lr = 1e0,
                                                steps_per_epoch=len(train_loader),
                                                epochs=epochs, pct_start=0.43, div_factor=10, final_div_factor=1000,
                                                three_phase=True)

# %%
train(model, optimiser_unet, scheduler, epochs)
loss, accuracy2, recall, precision, f1_score, confusion_matrix = evaluate(model, val_loader)
print("Loss: {:.4f}".format(loss))
print("Accuracy: {:.4f}".format(accuracy2))
print("Recall: {:.4f}".format(recall))
print("Precision: {:.4f}".format(precision))
print("F1 Score: {:.4f}".format(f1_score))
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# epoch: 296, mb: 1, train cost: 0.0039, val cost: 0.0037,train acc: 0.9987, val acc: 0.9987,dice: 0.8358138203620911, iou: 0.7179383039474487
# epoch: 296, mb: 2, train cost: 0.0056, val cost: 0.0040,train acc: 0.9974, val acc: 0.9987,dice: 0.8273280262947083, iou: 0.7055068016052246
# epoch: 296, mb: 3, train cost: 0.0050, val cost: 0.0040,train acc: 0.9977, val acc: 0.9986,dice: 0.8213790059089661, iou: 0.696898341178894
# epoch: 296, mb: 4, train cost: 0.0047, val cost: 0.0040,train acc: 0.9980, val acc: 0.9985,dice: 0.8136128187179565, iou: 0.6857903003692627
# epoch: 296, mb: 5, train cost: 0.0044, val cost: 0.0040,train acc: 0.9982, val acc: 0.9985,dice: 0.8095775842666626, iou: 0.6800758838653564
# epoch: 296, mb: 6, train cost: 0.0042, val cost: 0.0040,train acc: 0.9983, val acc: 0.9984,dice: 0.8078641891479492, iou: 0.6776611804962158
# epoch: 296, mb: 7, train cost: 0.0041, val cost: 0.0040,train acc: 0.9983, val acc: 0.9984,dice: 0.8052516579627991, iou: 0.6739926934242249
# epoch: 296, mb: 8, train cost: 0.0040, val cost: 0.0043,train acc: 0.9984, val acc: 0.9983,dice: 0.7962437272071838, iou: 0.6614658832550049
# epoch: 296, mb: 9, train cost: 0.0043, val cost: 0.0042,train acc: 0.9982, val acc: 0.9983,dice: 0.8000863790512085, iou: 0.6667866110801697
# epoch: 296, mb: 10, train cost: 0.0042, val cost: 0.0039,train acc: 0.9983, val acc: 0.9984,dice: 0.807750940322876, iou: 0.6775017976760864
# epoch: 296, mb: 11, train cost: 0.0041, val cost: 0.0039,train acc: 0.9983, val acc: 0.9985,dice: 0.8192393779754639, iou: 0.6938233971595764
# epoch: 297, mb: 1, train cost: 0.0041, val cost: 0.0037,train acc: 0.9983, val acc: 0.9987,dice: 0.832444965839386, iou: 0.7129813432693481
# epoch: 297, mb: 2, train cost: 0.0034, val cost: 0.0038,train acc: 0.9986, val acc: 0.9987,dice: 0.8360966444015503, iou: 0.7183557152748108
# epoch: 297, mb: 3, train cost: 0.0034, val cost: 0.0038,train acc: 0.9987, val acc: 0.9987,dice: 0.8346672654151917, iou: 0.7162480354309082
# epoch: 297, mb: 4, train cost: 0.0034, val cost: 0.0038,train acc: 0.9988, val acc: 0.9985,dice: 0.8241733908653259, iou: 0.7009310722351074
# epoch: 297, mb: 5, train cost: 0.0042, val cost: 0.0036,train acc: 0.9982, val acc: 0.9987,dice: 0.8338922262191772, iou: 0.7151073813438416
# epoch: 297, mb: 6, train cost: 0.0041, val cost: 0.0037,train acc: 0.9983, val acc: 0.9988,dice: 0.8434802889823914, iou: 0.7293263673782349
# epoch: 297, mb: 7, train cost: 0.0040, val cost: 0.0038,train acc: 0.9984, val acc: 0.9987,dice: 0.8293269276618958, iou: 0.7084189057350159
# epoch: 297, mb: 8, train cost: 0.0039, val cost: 0.0037,train acc: 0.9985, val acc: 0.9988,dice: 0.8404778838157654, iou: 0.7248485088348389
# epoch: 297, mb: 9, train cost: 0.0042, val cost: 0.0038,train acc: 0.9983, val acc: 0.9985,dice: 0.8208596706390381, iou: 0.6961510181427002
# epoch: 297, mb: 10, train cost: 0.0042, val cost: 0.0041,train acc: 0.9983, val acc: 0.9984,dice: 0.8065826296806335, iou: 0.6758595705032349
# epoch: 297, mb: 11, train cost: 0.0041, val cost: 0.0041,train acc: 0.9983, val acc: 0.9984,dice: 0.8056628108024597, iou: 0.6745689511299133
# epoch: 298, mb: 1, train cost: 0.0071, val cost: 0.0041,train acc: 0.9966, val acc: 0.9983,dice: 0.8025723695755005, iou: 0.6702470183372498
# epoch: 298, mb: 2, train cost: 0.0056, val cost: 0.0039,train acc: 0.9974, val acc: 0.9985,dice: 0.8138605356216431, iou: 0.6861423254013062
# epoch: 298, mb: 3, train cost: 0.0058, val cost: 0.0039,train acc: 0.9973, val acc: 0.9986,dice: 0.8191080093383789, iou: 0.6936349868774414
# epoch: 298, mb: 4, train cost: 0.0051, val cost: 0.0040,train acc: 0.9977, val acc: 0.9985,dice: 0.8165869116783142, iou: 0.6900269389152527
# epoch: 298, mb: 5, train cost: 0.0048, val cost: 0.0038,train acc: 0.9979, val acc: 0.9985,dice: 0.8121896386146545, iou: 0.6837704181671143
# epoch: 298, mb: 6, train cost: 0.0049, val cost: 0.0040,train acc: 0.9978, val acc: 0.9984,dice: 0.8096396327018738, iou: 0.6801634430885315
# epoch: 298, mb: 7, train cost: 0.0047, val cost: 0.0039,train acc: 0.9980, val acc: 0.9985,dice: 0.8146542310714722, iou: 0.6872714161872864
# epoch: 298, mb: 8, train cost: 0.0045, val cost: 0.0040,train acc: 0.9981, val acc: 0.9983,dice: 0.8051009774208069, iou: 0.6737815737724304
# epoch: 298, mb: 9, train cost: 0.0044, val cost: 0.0040,train acc: 0.9982, val acc: 0.9983,dice: 0.8052777051925659, iou: 0.6740292310714722
# epoch: 298, mb: 10, train cost: 0.0043, val cost: 0.0037,train acc: 0.9982, val acc: 0.9985,dice: 0.8171806335449219, iou: 0.690875232219696
# epoch: 298, mb: 11, train cost: 0.0041, val cost: 0.0038,train acc: 0.9983, val acc: 0.9987,dice: 0.8381801247596741, iou: 0.7214372158050537
# epoch: 299, mb: 1, train cost: 0.0034, val cost: 0.0037,train acc: 0.9988, val acc: 0.9988,dice: 0.8362318873405457, iou: 0.7185553908348083
# epoch: 299, mb: 2, train cost: 0.0050, val cost: 0.0039,train acc: 0.9977, val acc: 0.9988,dice: 0.8353702425956726, iou: 0.7172839641571045
# epoch: 299, mb: 3, train cost: 0.0044, val cost: 0.0040,train acc: 0.9981, val acc: 0.9986,dice: 0.8278538584709167, iou: 0.7062718868255615
# epoch: 299, mb: 4, train cost: 0.0042, val cost: 0.0039,train acc: 0.9983, val acc: 0.9985,dice: 0.818684995174408, iou: 0.6930285096168518
# epoch: 299, mb: 5, train cost: 0.0046, val cost: 0.0042,train acc: 0.9981, val acc: 0.9983,dice: 0.8033490777015686, iou: 0.6713311672210693
# epoch: 299, mb: 6, train cost: 0.0046, val cost: 0.0040,train acc: 0.9981, val acc: 0.9984,dice: 0.8107522130012512, iou: 0.6817353367805481
# epoch: 299, mb: 7, train cost: 0.0046, val cost: 0.0038,train acc: 0.9981, val acc: 0.9986,dice: 0.8295557498931885, iou: 0.7087529301643372
# epoch: 299, mb: 8, train cost: 0.0044, val cost: 0.0037,train acc: 0.9982, val acc: 0.9987,dice: 0.836245059967041, iou: 0.7185748815536499
# epoch: 299, mb: 9, train cost: 0.0042, val cost: 0.0035,train acc: 0.9982, val acc: 0.9988,dice: 0.838646411895752, iou: 0.7221283912658691
# epoch: 299, mb: 10, train cost: 0.0041, val cost: 0.0036,train acc: 0.9983, val acc: 0.9988,dice: 0.8427156209945679, iou: 0.7281836867332458
# epoch: 299, mb: 11, train cost: 0.0042, val cost: 0.0039,train acc: 0.9983, val acc: 0.9984,dice: 0.8151024580001831, iou: 0.6879096627235413
# epoch: 300, mb: 1, train cost: 0.0082, val cost: 0.0040,train acc: 0.9956, val acc: 0.9983,dice: 0.8056654930114746, iou: 0.6745727062225342
# epoch: 300, mb: 2, train cost: 0.0057, val cost: 0.0040,train acc: 0.9972, val acc: 0.9983,dice: 0.8039743304252625, iou: 0.6722049117088318
# epoch: 300, mb: 3, train cost: 0.0050, val cost: 0.0038,train acc: 0.9977, val acc: 0.9984,dice: 0.8173912763595581, iou: 0.6911764740943909
# epoch: 300, mb: 4, train cost: 0.0049, val cost: 0.0035,train acc: 0.9978, val acc: 0.9987,dice: 0.8375450968742371, iou: 0.7204968929290771
# epoch: 300, mb: 5, train cost: 0.0046, val cost: 0.0037,train acc: 0.9980, val acc: 0.9988,dice: 0.8320592045783997, iou: 0.7124155163764954
# epoch: 300, mb: 6, train cost: 0.0047, val cost: 0.0035,train acc: 0.9979, val acc: 0.9988,dice: 0.8426299691200256, iou: 0.7280557751655579
# epoch: 300, mb: 7, train cost: 0.0045, val cost: 0.0036,train acc: 0.9981, val acc: 0.9987,dice: 0.8344163298606873, iou: 0.7158784866333008
# epoch: 300, mb: 8, train cost: 0.0042, val cost: 0.0036,train acc: 0.9982, val acc: 0.9986,dice: 0.8253968358039856, iou: 0.7027027010917664
# epoch: 300, mb: 9, train cost: 0.0042, val cost: 0.0039,train acc: 0.9983, val acc: 0.9985,dice: 0.818693220615387, iou: 0.6930403113365173
# epoch: 300, mb: 10, train cost: 0.0041, val cost: 0.0040,train acc: 0.9983, val acc: 0.9984,dice: 0.8118128776550293, iou: 0.6832365989685059
# epoch: 300, mb: 11, train cost: 0.0041, val cost: 0.0038,train acc: 0.9983, val acc: 0.9985,dice: 0.8179795145988464, iou: 0.6920180916786194
# epoch: 301, mb: 1, train cost: 0.0033, val cost: 0.0038,train acc: 0.9987, val acc: 0.9986,dice: 0.8259052634239197, iou: 0.7034400701522827
# epoch: 301, mb: 2, train cost: 0.0050, val cost: 0.0039,train acc: 0.9978, val acc: 0.9986,dice: 0.8245203495025635, iou: 0.7014331221580505
# epoch: 301, mb: 3, train cost: 0.0047, val cost: 0.0037,train acc: 0.9980, val acc: 0.9987,dice: 0.8323917388916016, iou: 0.7129032015800476
# epoch: 301, mb: 4, train cost: 0.0045, val cost: 0.0036,train acc: 0.9980, val acc: 0.9987,dice: 0.8362882733345032, iou: 0.7186387181282043
# epoch: 301, mb: 5, train cost: 0.0042, val cost: 0.0035,train acc: 0.9982, val acc: 0.9987,dice: 0.8406264185905457, iou: 0.725069522857666
# epoch: 301, mb: 6, train cost: 0.0040, val cost: 0.0036,train acc: 0.9984, val acc: 0.9987,dice: 0.8345813751220703, iou: 0.71612149477005
# epoch: 301, mb: 7, train cost: 0.0039, val cost: 0.0037,train acc: 0.9984, val acc: 0.9986,dice: 0.82268226146698, iou: 0.6987767815589905
# epoch: 301, mb: 8, train cost: 0.0038, val cost: 0.0037,train acc: 0.9985, val acc: 0.9986,dice: 0.8288288116455078, iou: 0.7076923251152039
# epoch: 301, mb: 9, train cost: 0.0040, val cost: 0.0039,train acc: 0.9984, val acc: 0.9985,dice: 0.8011724352836609, iou: 0.6682966351509094
# epoch: 301, mb: 10, train cost: 0.0041, val cost: 0.0051,train acc: 0.9984, val acc: 0.9975,dice: 0.7377080321311951, iou: 0.5844195485115051
# epoch: 301, mb: 11, train cost: 0.0040, val cost: 0.0061,train acc: 0.9984, val acc: 0.9969,dice: 0.6944544911384583, iou: 0.531926691532135
# epoch: 302, mb: 1, train cost: 0.0043, val cost: 0.0047,train acc: 0.9980, val acc: 0.9980,dice: 0.7702100276947021, iou: 0.6262940168380737
# epoch: 302, mb: 2, train cost: 0.0052, val cost: 0.0043,train acc: 0.9976, val acc: 0.9985,dice: 0.7899452447891235, iou: 0.6528177857398987
# epoch: 302, mb: 3, train cost: 0.0049, val cost: 0.0048,train acc: 0.9979, val acc: 0.9984,dice: 0.752415120601654, iou: 0.6030973196029663
# epoch: 302, mb: 4, train cost: 0.0046, val cost: 0.0041,train acc: 0.9980, val acc: 0.9986,dice: 0.8205006122589111, iou: 0.6956346035003662
# epoch: 302, mb: 5, train cost: 0.0051, val cost: 0.0043,train acc: 0.9977, val acc: 0.9983,dice: 0.7955612540245056, iou: 0.6605244278907776
# epoch: 302, mb: 6, train cost: 0.0049, val cost: 0.0047,train acc: 0.9979, val acc: 0.9979,dice: 0.7724467515945435, iou: 0.6292572021484375
# epoch: 302, mb: 7, train cost: 0.0052, val cost: 0.0048,train acc: 0.9977, val acc: 0.9979,dice: 0.7682614922523499, iou: 0.6237212419509888
# epoch: 302, mb: 8, train cost: 0.0050, val cost: 0.0046,train acc: 0.9978, val acc: 0.9980,dice: 0.778113067150116, iou: 0.6368126273155212
# epoch: 302, mb: 9, train cost: 0.0048, val cost: 0.0040,train acc: 0.9979, val acc: 0.9984,dice: 0.8130045533180237, iou: 0.684926450252533
# epoch: 302, mb: 10, train cost: 0.0047, val cost: 0.0039,train acc: 0.9980, val acc: 0.9987,dice: 0.8333333134651184, iou: 0.7142857313156128
# epoch: 302, mb: 11, train cost: 0.0046, val cost: 0.0039,train acc: 0.9980, val acc: 0.9987,dice: 0.8308823704719543, iou: 0.7106918096542358
# epoch: 303, mb: 1, train cost: 0.0030, val cost: 0.0038,train acc: 0.9989, val acc: 0.9987,dice: 0.8319348096847534, iou: 0.7122331857681274
# epoch: 303, mb: 2, train cost: 0.0031, val cost: 0.0037,train acc: 0.9989, val acc: 0.9987,dice: 0.8307059407234192, iou: 0.7104337811470032
# epoch: 303, mb: 3, train cost: 0.0033, val cost: 0.0039,train acc: 0.9988, val acc: 0.9984,dice: 0.8146067261695862, iou: 0.6872037649154663
# epoch: 303, mb: 4, train cost: 0.0033, val cost: 0.0039,train acc: 0.9988, val acc: 0.9985,dice: 0.8166014552116394, iou: 0.6900477409362793
# epoch: 303, mb: 5, train cost: 0.0040, val cost: 0.0040,train acc: 0.9984, val acc: 0.9984,dice: 0.8158458471298218, iou: 0.6889692544937134
# epoch: 303, mb: 6, train cost: 0.0041, val cost: 0.0039,train acc: 0.9983, val acc: 0.9984,dice: 0.8116496801376343, iou: 0.6830053925514221
# epoch: 303, mb: 7, train cost: 0.0044, val cost: 0.0038,train acc: 0.9982, val acc: 0.9985,dice: 0.8208242654800415, iou: 0.6961000561714172
# epoch: 303, mb: 8, train cost: 0.0045, val cost: 0.0037,train acc: 0.9981, val acc: 0.9987,dice: 0.8378804922103882, iou: 0.7209933996200562
# epoch: 303, mb: 9, train cost: 0.0044, val cost: 0.0035,train acc: 0.9982, val acc: 0.9988,dice: 0.8390337228775024, iou: 0.7227029204368591
# epoch: 303, mb: 10, train cost: 0.0043, val cost: 0.0038,train acc: 0.9983, val acc: 0.9985,dice: 0.8237069249153137, iou: 0.7002565264701843
# epoch: 303, mb: 11, train cost: 0.0041, val cost: 0.0037,train acc: 0.9983, val acc: 0.9986,dice: 0.8313120007514954, iou: 0.7113207578659058
# epoch: 304, mb: 1, train cost: 0.0037, val cost: 0.0038,train acc: 0.9986, val acc: 0.9988,dice: 0.8467223048210144, iou: 0.734187662601471
# epoch: 304, mb: 2, train cost: 0.0035, val cost: 0.0037,train acc: 0.9987, val acc: 0.9988,dice: 0.8457639217376709, iou: 0.7327477931976318
# epoch: 304, mb: 3, train cost: 0.0046, val cost: 0.0044,train acc: 0.9981, val acc: 0.9985,dice: 0.7811649441719055, iou: 0.6409111022949219
# epoch: 304, mb: 4, train cost: 0.0042, val cost: 0.0037,train acc: 0.9983, val acc: 0.9986,dice: 0.8258750438690186, iou: 0.703396201133728
# epoch: 304, mb: 5, train cost: 0.0042, val cost: 0.0044,train acc: 0.9983, val acc: 0.9981,dice: 0.7815573811531067, iou: 0.6414396166801453
# epoch: 304, mb: 6, train cost: 0.0041, val cost: 0.0048,train acc: 0.9983, val acc: 0.9979,dice: 0.7661097645759583, iou: 0.6208897233009338
# epoch: 304, mb: 7, train cost: 0.0045, val cost: 0.0047,train acc: 0.9981, val acc: 0.9978,dice: 0.7622836828231812, iou: 0.6158791184425354
# epoch: 304, mb: 8, train cost: 0.0043, val cost: 0.0045,train acc: 0.9982, val acc: 0.9981,dice: 0.7798013091087341, iou: 0.639077365398407
# epoch: 304, mb: 9, train cost: 0.0042, val cost: 0.0042,train acc: 0.9983, val acc: 0.9984,dice: 0.8027771711349487, iou: 0.6705328226089478
# epoch: 304, mb: 10, train cost: 0.0041, val cost: 0.0040,train acc: 0.9983, val acc: 0.9985,dice: 0.8129205703735352, iou: 0.6848072409629822
# epoch: 304, mb: 11, train cost: 0.0040, val cost: 0.0039,train acc: 0.9983, val acc: 0.9987,dice: 0.829383909702301, iou: 0.7085019946098328
# epoch: 305, mb: 1, train cost: 0.0036, val cost: 0.0039,train acc: 0.9988, val acc: 0.9987,dice: 0.832504153251648, iou: 0.7130681872367859
# epoch: 305, mb: 2, train cost: 0.0033, val cost: 0.0039,train acc: 0.9989, val acc: 0.9987,dice: 0.8328571319580078, iou: 0.7135862708091736
# epoch: 305, mb: 3, train cost: 0.0040, val cost: 0.0037,train acc: 0.9984, val acc: 0.9988,dice: 0.8431326150894165, iou: 0.7288065552711487
# epoch: 305, mb: 4, train cost: 0.0037, val cost: 0.0037,train acc: 0.9986, val acc: 0.9988,dice: 0.8426275849342346, iou: 0.7280522584915161
# epoch: 305, mb: 5, train cost: 0.0035, val cost: 0.0039,train acc: 0.9987, val acc: 0.9987,dice: 0.8326340317726135, iou: 0.7132588028907776
# epoch: 305, mb: 6, train cost: 0.0037, val cost: 0.0038,train acc: 0.9986, val acc: 0.9987,dice: 0.8320366144180298, iou: 0.712382435798645
# epoch: 305, mb: 7, train cost: 0.0037, val cost: 0.0039,train acc: 0.9986, val acc: 0.9984,dice: 0.8094097375869751, iou: 0.679839015007019
# epoch: 305, mb: 8, train cost: 0.0036, val cost: 0.0044,train acc: 0.9987, val acc: 0.9982,dice: 0.7874245047569275, iou: 0.6493818759918213
# epoch: 305, mb: 9, train cost: 0.0037, val cost: 0.0042,train acc: 0.9986, val acc: 0.9981,dice: 0.7889643907546997, iou: 0.6514790654182434
# epoch: 305, mb: 10, train cost: 0.0040, val cost: 0.0040,train acc: 0.9984, val acc: 0.9984,dice: 0.8062247037887573, iou: 0.6753571629524231
# epoch: 305, mb: 11, train cost: 0.0039, val cost: 0.0037,train acc: 0.9984, val acc: 0.9987,dice: 0.8281505703926086, iou: 0.7067039012908936
# epoch: 306, mb: 1, train cost: 0.0051, val cost: 0.0040,train acc: 0.9976, val acc: 0.9987,dice: 0.8165091872215271, iou: 0.6899159550666809
# epoch: 306, mb: 2, train cost: 0.0046, val cost: 0.0038,train acc: 0.9981, val acc: 0.9986,dice: 0.8200277090072632, iou: 0.694955050945282
# epoch: 306, mb: 3, train cost: 0.0040, val cost: 0.0043,train acc: 0.9984, val acc: 0.9982,dice: 0.7929120659828186, iou: 0.6568800806999207
# epoch: 306, mb: 4, train cost: 0.0039, val cost: 0.0043,train acc: 0.9985, val acc: 0.9981,dice: 0.7821782231330872, iou: 0.642276406288147
# epoch: 306, mb: 5, train cost: 0.0039, val cost: 0.0045,train acc: 0.9985, val acc: 0.9979,dice: 0.7679771780967712, iou: 0.6233465671539307
# epoch: 306, mb: 6, train cost: 0.0038, val cost: 0.0045,train acc: 0.9986, val acc: 0.9980,dice: 0.7730393409729004, iou: 0.6300441026687622
# epoch: 306, mb: 7, train cost: 0.0039, val cost: 0.0041,train acc: 0.9984, val acc: 0.9985,dice: 0.8073647618293762, iou: 0.6769586801528931
# epoch: 306, mb: 8, train cost: 0.0041, val cost: 0.0038,train acc: 0.9983, val acc: 0.9988,dice: 0.8262295126914978, iou: 0.7039105892181396
# epoch: 306, mb: 9, train cost: 0.0042, val cost: 0.0037,train acc: 0.9983, val acc: 0.9988,dice: 0.8380717039108276, iou: 0.721276581287384
# epoch: 306, mb: 10, train cost: 0.0041, val cost: 0.0037,train acc: 0.9984, val acc: 0.9986,dice: 0.827399730682373, iou: 0.7056110501289368
# epoch: 306, mb: 11, train cost: 0.0040, val cost: 0.0038,train acc: 0.9984, val acc: 0.9985,dice: 0.8200525641441345, iou: 0.6949906945228577
# epoch: 307, mb: 1, train cost: 0.0030, val cost: 0.0038,train acc: 0.9991, val acc: 0.9986,dice: 0.8248191475868225, iou: 0.7018656730651855
# epoch: 307, mb: 2, train cost: 0.0043, val cost: 0.0038,train acc: 0.9983, val acc: 0.9986,dice: 0.8235294222831726, iou: 0.699999988079071
# epoch: 307, mb: 3, train cost: 0.0040, val cost: 0.0037,train acc: 0.9984, val acc: 0.9986,dice: 0.8299441337585449, iou: 0.709320068359375
# epoch: 307, mb: 4, train cost: 0.0040, val cost: 0.0037,train acc: 0.9984, val acc: 0.9986,dice: 0.8261942267417908, iou: 0.7038593888282776
# epoch: 307, mb: 5, train cost: 0.0040, val cost: 0.0036,train acc: 0.9984, val acc: 0.9987,dice: 0.8239753842353821, iou: 0.7006446123123169
# epoch: 307, mb: 6, train cost: 0.0039, val cost: 0.0036,train acc: 0.9985, val acc: 0.9988,dice: 0.8363636136054993, iou: 0.71875
# epoch: 307, mb: 7, train cost: 0.0041, val cost: 0.0036,train acc: 0.9983, val acc: 0.9987,dice: 0.8315741419792175, iou: 0.7117046117782593
# epoch: 307, mb: 8, train cost: 0.0040, val cost: 0.0041,train acc: 0.9984, val acc: 0.9982,dice: 0.7968127727508545, iou: 0.6622516512870789
# epoch: 307, mb: 9, train cost: 0.0039, val cost: 0.0040,train acc: 0.9984, val acc: 0.9983,dice: 0.8045048713684082, iou: 0.6729470491409302
# epoch: 307, mb: 10, train cost: 0.0039, val cost: 0.0040,train acc: 0.9985, val acc: 0.9984,dice: 0.8032969236373901, iou: 0.6712583899497986
# epoch: 307, mb: 11, train cost: 0.0039, val cost: 0.0040,train acc: 0.9985, val acc: 0.9985,dice: 0.8082502484321594, iou: 0.6782046556472778
# epoch: 308, mb: 1, train cost: 0.0033, val cost: 0.0043,train acc: 0.9988, val acc: 0.9981,dice: 0.7855960130691528, iou: 0.6468984484672546
# epoch: 308, mb: 2, train cost: 0.0035, val cost: 0.0042,train acc: 0.9986, val acc: 0.9983,dice: 0.7966893315315247, iou: 0.6620811223983765
# epoch: 308, mb: 3, train cost: 0.0036, val cost: 0.0039,train acc: 0.9985, val acc: 0.9986,dice: 0.8188868761062622, iou: 0.6933178901672363
# epoch: 308, mb: 4, train cost: 0.0037, val cost: 0.0039,train acc: 0.9985, val acc: 0.9986,dice: 0.8264955282211304, iou: 0.704296886920929
# epoch: 308, mb: 5, train cost: 0.0035, val cost: 0.0038,train acc: 0.9987, val acc: 0.9986,dice: 0.8247232437133789, iou: 0.7017268538475037
# epoch: 308, mb: 6, train cost: 0.0034, val cost: 0.0039,train acc: 0.9987, val acc: 0.9987,dice: 0.8272300362586975, iou: 0.7053642868995667
# epoch: 308, mb: 7, train cost: 0.0034, val cost: 0.0039,train acc: 0.9987, val acc: 0.9987,dice: 0.828900933265686, iou: 0.7077974081039429
# epoch: 308, mb: 8, train cost: 0.0037, val cost: 0.0039,train acc: 0.9985, val acc: 0.9985,dice: 0.8165812492370605, iou: 0.6900188326835632
# epoch: 308, mb: 9, train cost: 0.0037, val cost: 0.0040,train acc: 0.9985, val acc: 0.9984,dice: 0.8127300143241882, iou: 0.6845368146896362
# epoch: 308, mb: 10, train cost: 0.0039, val cost: 0.0044,train acc: 0.9985, val acc: 0.9982,dice: 0.7977020740509033, iou: 0.6634812355041504
# epoch: 308, mb: 11, train cost: 0.0039, val cost: 0.0042,train acc: 0.9985, val acc: 0.9982,dice: 0.7992603182792664, iou: 0.6656399965286255
# epoch: 309, mb: 1, train cost: 0.0036, val cost: 0.0043,train acc: 0.9986, val acc: 0.9981,dice: 0.7891737818717957, iou: 0.6517646908760071
# epoch: 309, mb: 2, train cost: 0.0034, val cost: 0.0040,train acc: 0.9987, val acc: 0.9984,dice: 0.8134793043136597, iou: 0.6856005787849426
# epoch: 309, mb: 3, train cost: 0.0033, val cost: 0.0039,train acc: 0.9987, val acc: 0.9986,dice: 0.8228996992111206, iou: 0.6990905404090881
# epoch: 309, mb: 4, train cost: 0.0033, val cost: 0.0040,train acc: 0.9988, val acc: 0.9986,dice: 0.8213180899620056, iou: 0.6968106627464294
# epoch: 309, mb: 5, train cost: 0.0034, val cost: 0.0038,train acc: 0.9987, val acc: 0.9988,dice: 0.8377862572669983, iou: 0.720853865146637
# epoch: 309, mb: 6, train cost: 0.0035, val cost: 0.0040,train acc: 0.9987, val acc: 0.9984,dice: 0.8058936595916748, iou: 0.6748927235603333
# epoch: 309, mb: 7, train cost: 0.0033, val cost: 0.0043,train acc: 0.9988, val acc: 0.9981,dice: 0.7883151769638062, iou: 0.6505942344665527
# epoch: 309, mb: 8, train cost: 0.0034, val cost: 0.0048,train acc: 0.9988, val acc: 0.9979,dice: 0.767139732837677, iou: 0.6222438216209412
# epoch: 309, mb: 9, train cost: 0.0038, val cost: 0.0042,train acc: 0.9985, val acc: 0.9982,dice: 0.7939124703407288, iou: 0.6582544445991516
# epoch: 309, mb: 10, train cost: 0.0040, val cost: 0.0038,train acc: 0.9984, val acc: 0.9986,dice: 0.8212135434150696, iou: 0.6966601014137268
# epoch: 309, mb: 11, train cost: 0.0040, val cost: 0.0042,train acc: 0.9984, val acc: 0.9986,dice: 0.8039114475250244, iou: 0.6721170544624329
# epoch: 310, mb: 1, train cost: 0.0060, val cost: 0.0041,train acc: 0.9976, val acc: 0.9986,dice: 0.8031819462776184, iou: 0.6710977554321289
# epoch: 310, mb: 2, train cost: 0.0051, val cost: 0.0044,train acc: 0.9981, val acc: 0.9981,dice: 0.7825717329978943, iou: 0.6428072452545166
# epoch: 310, mb: 3, train cost: 0.0046, val cost: 0.0050,train acc: 0.9983, val acc: 0.9975,dice: 0.738182544708252, iou: 0.5850152969360352
# epoch: 310, mb: 4, train cost: 0.0046, val cost: 0.0051,train acc: 0.9983, val acc: 0.9976,dice: 0.7402121424674988, iou: 0.5875688791275024
# epoch: 310, mb: 5, train cost: 0.0043, val cost: 0.0046,train acc: 0.9984, val acc: 0.9979,dice: 0.7631896734237671, iou: 0.6170628666877747
# epoch: 310, mb: 6, train cost: 0.0042, val cost: 0.0042,train acc: 0.9984, val acc: 0.9984,dice: 0.8001758456230164, iou: 0.6669109463691711
# epoch: 310, mb: 7, train cost: 0.0043, val cost: 0.0040,train acc: 0.9983, val acc: 0.9987,dice: 0.8216942548751831, iou: 0.6973523497581482
# epoch: 310, mb: 8, train cost: 0.0041, val cost: 0.0041,train acc: 0.9984, val acc: 0.9987,dice: 0.8244693875312805, iou: 0.7013593912124634
# epoch: 310, mb: 9, train cost: 0.0043, val cost: 0.0038,train acc: 0.9982, val acc: 0.9988,dice: 0.8334574103355408, iou: 0.7144680619239807
# epoch: 310, mb: 10, train cost: 0.0042, val cost: 0.0038,train acc: 0.9983, val acc: 0.9987,dice: 0.836825966835022, iou: 0.7194331884384155
# epoch: 310, mb: 11, train cost: 0.0041, val cost: 0.0042,train acc: 0.9983, val acc: 0.9982,dice: 0.7960922718048096, iou: 0.6612569093704224
# epoch: 311, mb: 1, train cost: 0.0027, val cost: 0.0043,train acc: 0.9990, val acc: 0.9980,dice: 0.7797891497612, iou: 0.6390609741210938
# epoch: 311, mb: 2, train cost: 0.0030, val cost: 0.0047,train acc: 0.9989, val acc: 0.9978,dice: 0.7676845788955688, iou: 0.6229611039161682
# epoch: 311, mb: 3, train cost: 0.0032, val cost: 0.0047,train acc: 0.9988, val acc: 0.9978,dice: 0.7679504752159119, iou: 0.6233113408088684
# epoch: 311, mb: 4, train cost: 0.0034, val cost: 0.0045,train acc: 0.9987, val acc: 0.9979,dice: 0.7753809690475464, iou: 0.6331609487533569
# epoch: 311, mb: 5, train cost: 0.0039, val cost: 0.0042,train acc: 0.9984, val acc: 0.9983,dice: 0.8019303679466248, iou: 0.6693519949913025
# epoch: 311, mb: 6, train cost: 0.0041, val cost: 0.0040,train acc: 0.9983, val acc: 0.9987,dice: 0.8314502835273743, iou: 0.7115232944488525
# epoch: 311, mb: 7, train cost: 0.0040, val cost: 0.0039,train acc: 0.9984, val acc: 0.9987,dice: 0.8309859037399292, iou: 0.7108433842658997
# epoch: 311, mb: 8, train cost: 0.0043, val cost: 0.0038,train acc: 0.9982, val acc: 0.9987,dice: 0.8328912258148193, iou: 0.7136363387107849
# epoch: 311, mb: 9, train cost: 0.0042, val cost: 0.0038,train acc: 0.9982, val acc: 0.9987,dice: 0.831539511680603, iou: 0.711654007434845
# epoch: 311, mb: 10, train cost: 0.0042, val cost: 0.0040,train acc: 0.9983, val acc: 0.9984,dice: 0.8124863505363464, iou: 0.6841911673545837
# epoch: 311, mb: 11, train cost: 0.0042, val cost: 0.0041,train acc: 0.9983, val acc: 0.9983,dice: 0.8006865382194519, iou: 0.6676207780838013
# epoch: 312, mb: 1, train cost: 0.0033, val cost: 0.0041,train acc: 0.9989, val acc: 0.9983,dice: 0.8009529709815979, iou: 0.6679913401603699
# epoch: 312, mb: 2, train cost: 0.0030, val cost: 0.0041,train acc: 0.9989, val acc: 0.9984,dice: 0.8037835359573364, iou: 0.6719382405281067
# epoch: 312, mb: 3, train cost: 0.0038, val cost: 0.0038,train acc: 0.9985, val acc: 0.9986,dice: 0.8241506218910217, iou: 0.7008981108665466
# epoch: 312, mb: 4, train cost: 0.0041, val cost: 0.0038,train acc: 0.9983, val acc: 0.9987,dice: 0.8278370499610901, iou: 0.7062473893165588
# epoch: 312, mb: 5, train cost: 0.0041, val cost: 0.0038,train acc: 0.9983, val acc: 0.9986,dice: 0.8233664035797119, iou: 0.6997645497322083
# epoch: 312, mb: 6, train cost: 0.0040, val cost: 0.0039,train acc: 0.9984, val acc: 0.9984,dice: 0.8079413175582886, iou: 0.6777697205543518
# epoch: 312, mb: 7, train cost: 0.0039, val cost: 0.0042,train acc: 0.9985, val acc: 0.9981,dice: 0.7866503000259399, iou: 0.6483293771743774
# epoch: 312, mb: 8, train cost: 0.0039, val cost: 0.0042,train acc: 0.9985, val acc: 0.9982,dice: 0.793899416923523, iou: 0.6582365036010742
# epoch: 312, mb: 9, train cost: 0.0038, val cost: 0.0041,train acc: 0.9985, val acc: 0.9984,dice: 0.8065546154975891, iou: 0.6758202314376831
# epoch: 312, mb: 10, train cost: 0.0040, val cost: 0.0037,train acc: 0.9984, val acc: 0.9987,dice: 0.8346492052078247, iou: 0.7162214517593384
# epoch: 312, mb: 11, train cost: 0.0040, val cost: 0.0040,train acc: 0.9984, val acc: 0.9986,dice: 0.8242290616035461, iou: 0.701011598110199
# epoch: 313, mb: 1, train cost: 0.0038, val cost: 0.0042,train acc: 0.9986, val acc: 0.9983,dice: 0.8053634762763977, iou: 0.6741493940353394
# epoch: 313, mb: 2, train cost: 0.0038, val cost: 0.0046,train acc: 0.9986, val acc: 0.9980,dice: 0.7785829305648804, iou: 0.6374422907829285
# epoch: 313, mb: 3, train cost: 0.0045, val cost: 0.0042,train acc: 0.9982, val acc: 0.9984,dice: 0.8119567632675171, iou: 0.6834403872489929
# epoch: 313, mb: 4, train cost: 0.0044, val cost: 0.0037,train acc: 0.9982, val acc: 0.9986,dice: 0.8303248882293701, iou: 0.709876537322998
# epoch: 313, mb: 5, train cost: 0.0043, val cost: 0.0041,train acc: 0.9983, val acc: 0.9985,dice: 0.8123324513435364, iou: 0.6839728951454163
# epoch: 313, mb: 6, train cost: 0.0045, val cost: 0.0037,train acc: 0.9981, val acc: 0.9988,dice: 0.8387573957443237, iou: 0.7222930192947388
# epoch: 313, mb: 7, train cost: 0.0043, val cost: 0.0039,train acc: 0.9983, val acc: 0.9988,dice: 0.8312674164772034, iou: 0.7112554311752319
# epoch: 313, mb: 8, train cost: 0.0043, val cost: 0.0037,train acc: 0.9983, val acc: 0.9988,dice: 0.83984375, iou: 0.7239057421684265
# epoch: 313, mb: 9, train cost: 0.0041, val cost: 0.0037,train acc: 0.9984, val acc: 0.9987,dice: 0.8363889455795288, iou: 0.7187873721122742
# epoch: 313, mb: 10, train cost: 0.0040, val cost: 0.0039,train acc: 0.9984, val acc: 0.9986,dice: 0.8252426981925964, iou: 0.702479362487793
# epoch: 313, mb: 11, train cost: 0.0039, val cost: 0.0037,train acc: 0.9985, val acc: 0.9986,dice: 0.8296459913253784, iou: 0.7088847160339355
# epoch: 314, mb: 1, train cost: 0.0033, val cost: 0.0039,train acc: 0.9988, val acc: 0.9985,dice: 0.822698175907135, iou: 0.698799729347229
# epoch: 314, mb: 2, train cost: 0.0034, val cost: 0.0038,train acc: 0.9988, val acc: 0.9986,dice: 0.828082799911499, iou: 0.7066051959991455
# epoch: 314, mb: 3, train cost: 0.0032, val cost: 0.0037,train acc: 0.9989, val acc: 0.9988,dice: 0.8408982157707214, iou: 0.7254740595817566
# epoch: 314, mb: 4, train cost: 0.0034, val cost: 0.0035,train acc: 0.9988, val acc: 0.9988,dice: 0.8416224122047424, iou: 0.7265527248382568
# epoch: 314, mb: 5, train cost: 0.0034, val cost: 0.0036,train acc: 0.9988, val acc: 0.9987,dice: 0.8326097726821899, iou: 0.7132231593132019
# epoch: 314, mb: 6, train cost: 0.0038, val cost: 0.0036,train acc: 0.9986, val acc: 0.9987,dice: 0.8287292718887329, iou: 0.7075471878051758
# epoch: 314, mb: 7, train cost: 0.0037, val cost: 0.0043,train acc: 0.9986, val acc: 0.9982,dice: 0.7624576687812805, iou: 0.6161063313484192
# epoch: 314, mb: 8, train cost: 0.0037, val cost: 0.0039,train acc: 0.9986, val acc: 0.9985,dice: 0.818122386932373, iou: 0.6922226548194885
# epoch: 314, mb: 9, train cost: 0.0039, val cost: 0.0039,train acc: 0.9985, val acc: 0.9985,dice: 0.8116781711578369, iou: 0.6830457448959351
# epoch: 314, mb: 10, train cost: 0.0038, val cost: 0.0038,train acc: 0.9985, val acc: 0.9985,dice: 0.8109124898910522, iou: 0.6819620132446289
# epoch: 314, mb: 11, train cost: 0.0037, val cost: 0.0042,train acc: 0.9985, val acc: 0.9985,dice: 0.7999007105827332, iou: 0.6665287613868713
# epoch: 315, mb: 1, train cost: 0.0031, val cost: 0.0044,train acc: 0.9989, val acc: 0.9985,dice: 0.7889237403869629, iou: 0.6514236330986023
# epoch: 315, mb: 2, train cost: 0.0029, val cost: 0.0044,train acc: 0.9990, val acc: 0.9985,dice: 0.7848837375640869, iou: 0.6459330320358276
# epoch: 315, mb: 3, train cost: 0.0030, val cost: 0.0041,train acc: 0.9990, val acc: 0.9987,dice: 0.8178865909576416, iou: 0.6918850541114807
# epoch: 315, mb: 4, train cost: 0.0030, val cost: 0.0038,train acc: 0.9990, val acc: 0.9986,dice: 0.8219679594039917, iou: 0.6977466940879822
# epoch: 315, mb: 5, train cost: 0.0030, val cost: 0.0037,train acc: 0.9990, val acc: 0.9985,dice: 0.8214519023895264, iou: 0.6970033049583435
# epoch: 315, mb: 6, train cost: 0.0031, val cost: 0.0037,train acc: 0.9989, val acc: 0.9986,dice: 0.8282425999641418, iou: 0.7068379521369934
# epoch: 315, mb: 7, train cost: 0.0032, val cost: 0.0037,train acc: 0.9989, val acc: 0.9986,dice: 0.8266963362693787, iou: 0.7045885324478149
# epoch: 315, mb: 8, train cost: 0.0035, val cost: 0.0036,train acc: 0.9987, val acc: 0.9986,dice: 0.8312555551528931, iou: 0.7112380862236023
# epoch: 315, mb: 9, train cost: 0.0037, val cost: 0.0034,train acc: 0.9986, val acc: 0.9987,dice: 0.8426094651222229, iou: 0.7280251979827881
# epoch: 315, mb: 10, train cost: 0.0037, val cost: 0.0035,train acc: 0.9985, val acc: 0.9988,dice: 0.8473942279815674, iou: 0.7351986765861511
# epoch: 315, mb: 11, train cost: 0.0038, val cost: 0.0036,train acc: 0.9985, val acc: 0.9986,dice: 0.8284518718719482, iou: 0.7071428298950195
# epoch: 316, mb: 1, train cost: 0.0051, val cost: 0.0037,train acc: 0.9979, val acc: 0.9986,dice: 0.8257923722267151, iou: 0.7032762765884399
# epoch: 316, mb: 2, train cost: 0.0044, val cost: 0.0041,train acc: 0.9983, val acc: 0.9983,dice: 0.7984918355941772, iou: 0.6645746231079102
# epoch: 316, mb: 3, train cost: 0.0039, val cost: 0.0038,train acc: 0.9985, val acc: 0.9986,dice: 0.8322981595993042, iou: 0.7127659320831299
# epoch: 316, mb: 4, train cost: 0.0036, val cost: 0.0037,train acc: 0.9986, val acc: 0.9987,dice: 0.8283668160438538, iou: 0.7070189118385315
# epoch: 316, mb: 5, train cost: 0.0038, val cost: 0.0037,train acc: 0.9985, val acc: 0.9987,dice: 0.8270858526229858, iou: 0.7051546573638916
# epoch: 316, mb: 6, train cost: 0.0038, val cost: 0.0036,train acc: 0.9986, val acc: 0.9987,dice: 0.8370927572250366, iou: 0.7198275923728943
# epoch: 316, mb: 7, train cost: 0.0037, val cost: 0.0038,train acc: 0.9986, val acc: 0.9985,dice: 0.8208757042884827, iou: 0.6961740255355835
# epoch: 316, mb: 8, train cost: 0.0036, val cost: 0.0036,train acc: 0.9986, val acc: 0.9986,dice: 0.8301801681518555, iou: 0.7096650004386902
# epoch: 316, mb: 9, train cost: 0.0036, val cost: 0.0036,train acc: 0.9987, val acc: 0.9987,dice: 0.8406257033348083, iou: 0.7250684499740601
# epoch: 316, mb: 10, train cost: 0.0038, val cost: 0.0035,train acc: 0.9986, val acc: 0.9988,dice: 0.8422268629074097, iou: 0.7274541258811951
# epoch: 316, mb: 11, train cost: 0.0037, val cost: 0.0035,train acc: 0.9986, val acc: 0.9989,dice: 0.8502965569496155, iou: 0.7395790219306946
# epoch: 317, mb: 1, train cost: 0.0032, val cost: 0.0035,train acc: 0.9988, val acc: 0.9989,dice: 0.8522565364837646, iou: 0.7425496578216553
# epoch: 317, mb: 2, train cost: 0.0033, val cost: 0.0034,train acc: 0.9988, val acc: 0.9988,dice: 0.8487238883972168, iou: 0.7372027635574341
# epoch: 317, mb: 3, train cost: 0.0035, val cost: 0.0037,train acc: 0.9988, val acc: 0.9986,dice: 0.8324084281921387, iou: 0.7129277586936951
# epoch: 317, mb: 4, train cost: 0.0033, val cost: 0.0036,train acc: 0.9988, val acc: 0.9986,dice: 0.8268767595291138, iou: 0.7048507332801819
# epoch: 317, mb: 5, train cost: 0.0033, val cost: 0.0038,train acc: 0.9988, val acc: 0.9984,dice: 0.8144198060035706, iou: 0.6869377493858337
# epoch: 317, mb: 6, train cost: 0.0033, val cost: 0.0037,train acc: 0.9988, val acc: 0.9985,dice: 0.8199315667152405, iou: 0.6948169469833374
# epoch: 317, mb: 7, train cost: 0.0036, val cost: 0.0035,train acc: 0.9987, val acc: 0.9987,dice: 0.8369492292404175, iou: 0.7196153998374939
# epoch: 317, mb: 8, train cost: 0.0037, val cost: 0.0034,train acc: 0.9986, val acc: 0.9988,dice: 0.8442544937133789, iou: 0.7304847836494446
# epoch: 317, mb: 9, train cost: 0.0037, val cost: 0.0035,train acc: 0.9986, val acc: 0.9988,dice: 0.8422868251800537, iou: 0.7275436520576477
# epoch: 317, mb: 10, train cost: 0.0036, val cost: 0.0037,train acc: 0.9986, val acc: 0.9987,dice: 0.8215938210487366, iou: 0.6972076892852783
# epoch: 317, mb: 11, train cost: 0.0036, val cost: 0.0036,train acc: 0.9986, val acc: 0.9988,dice: 0.8457663655281067, iou: 0.7327514290809631
# epoch: 318, mb: 1, train cost: 0.0025, val cost: 0.0036,train acc: 0.9991, val acc: 0.9987,dice: 0.843031108379364, iou: 0.7286549806594849
# epoch: 318, mb: 2, train cost: 0.0030, val cost: 0.0038,train acc: 0.9989, val acc: 0.9984,dice: 0.8154849410057068, iou: 0.6884546875953674
# epoch: 318, mb: 3, train cost: 0.0036, val cost: 0.0042,train acc: 0.9986, val acc: 0.9982,dice: 0.7964242100715637, iou: 0.661715030670166
# epoch: 318, mb: 4, train cost: 0.0035, val cost: 0.0040,train acc: 0.9986, val acc: 0.9982,dice: 0.8004946708679199, iou: 0.6673539280891418
# epoch: 318, mb: 5, train cost: 0.0035, val cost: 0.0040,train acc: 0.9986, val acc: 0.9983,dice: 0.8058638572692871, iou: 0.6748509407043457
# epoch: 318, mb: 6, train cost: 0.0035, val cost: 0.0037,train acc: 0.9986, val acc: 0.9987,dice: 0.8350123167037964, iou: 0.7167563438415527
# epoch: 318, mb: 7, train cost: 0.0035, val cost: 0.0035,train acc: 0.9986, val acc: 0.9988,dice: 0.8456124067306519, iou: 0.732520341873169
# epoch: 318, mb: 8, train cost: 0.0035, val cost: 0.0036,train acc: 0.9986, val acc: 0.9988,dice: 0.8463768362998962, iou: 0.733668327331543
# epoch: 318, mb: 9, train cost: 0.0038, val cost: 0.0037,train acc: 0.9985, val acc: 0.9988,dice: 0.8455016613006592, iou: 0.7323541641235352
# epoch: 318, mb: 10, train cost: 0.0037, val cost: 0.0035,train acc: 0.9985, val acc: 0.9987,dice: 0.8370303511619568, iou: 0.719735324382782
# epoch: 318, mb: 11, train cost: 0.0037, val cost: 0.0037,train acc: 0.9985, val acc: 0.9986,dice: 0.8250166177749634, iou: 0.7021517753601074
# epoch: 319, mb: 1, train cost: 0.0061, val cost: 0.0038,train acc: 0.9973, val acc: 0.9985,dice: 0.814210057258606, iou: 0.6866393685340881
# epoch: 319, mb: 2, train cost: 0.0049, val cost: 0.0038,train acc: 0.9980, val acc: 0.9985,dice: 0.8178771138191223, iou: 0.6918714642524719
# epoch: 319, mb: 3, train cost: 0.0041, val cost: 0.0036,train acc: 0.9984, val acc: 0.9986,dice: 0.8288660049438477, iou: 0.7077465057373047
# epoch: 319, mb: 4, train cost: 0.0039, val cost: 0.0037,train acc: 0.9985, val acc: 0.9986,dice: 0.825541615486145, iou: 0.7029126286506653
# epoch: 319, mb: 5, train cost: 0.0038, val cost: 0.0037,train acc: 0.9985, val acc: 0.9987,dice: 0.8286705017089844, iou: 0.7074615359306335
# epoch: 319, mb: 6, train cost: 0.0037, val cost: 0.0037,train acc: 0.9986, val acc: 0.9988,dice: 0.8391181826591492, iou: 0.7228282690048218
# epoch: 319, mb: 7, train cost: 0.0037, val cost: 0.0034,train acc: 0.9986, val acc: 0.9988,dice: 0.8437644839286804, iou: 0.7297514081001282
# epoch: 319, mb: 8, train cost: 0.0036, val cost: 0.0035,train acc: 0.9986, val acc: 0.9987,dice: 0.8394043445587158, iou: 0.723253071308136
# epoch: 319, mb: 9, train cost: 0.0036, val cost: 0.0034,train acc: 0.9986, val acc: 0.9987,dice: 0.8369050025939941, iou: 0.7195500135421753
# epoch: 319, mb: 10, train cost: 0.0036, val cost: 0.0035,train acc: 0.9986, val acc: 0.9986,dice: 0.8334805369377136, iou: 0.7145020961761475
# epoch: 319, mb: 11, train cost: 0.0035, val cost: 0.0038,train acc: 0.9986, val acc: 0.9985,dice: 0.8201193809509277, iou: 0.6950867176055908
# epoch: 320, mb: 1, train cost: 0.0025, val cost: 0.0040,train acc: 0.9992, val acc: 0.9983,dice: 0.804888129234314, iou: 0.6734835505485535
# epoch: 320, mb: 2, train cost: 0.0032, val cost: 0.0040,train acc: 0.9989, val acc: 0.9984,dice: 0.8099138736724854, iou: 0.6805506348609924
# epoch: 320, mb: 3, train cost: 0.0044, val cost: 0.0036,train acc: 0.9982, val acc: 0.9987,dice: 0.8379411101341248, iou: 0.7210831642150879
# epoch: 320, mb: 4, train cost: 0.0040, val cost: 0.0036,train acc: 0.9985, val acc: 0.9988,dice: 0.8456700444221497, iou: 0.7326068878173828
# epoch: 320, mb: 5, train cost: 0.0038, val cost: 0.0036,train acc: 0.9985, val acc: 0.9989,dice: 0.8469560742378235, iou: 0.7345393300056458
# epoch: 320, mb: 6, train cost: 0.0037, val cost: 0.0036,train acc: 0.9986, val acc: 0.9988,dice: 0.8460458517074585, iou: 0.7331711053848267
# epoch: 320, mb: 7, train cost: 0.0037, val cost: 0.0035,train acc: 0.9986, val acc: 0.9987,dice: 0.8391608595848083, iou: 0.7228915691375732
# epoch: 320, mb: 8, train cost: 0.0037, val cost: 0.0037,train acc: 0.9986, val acc: 0.9985,dice: 0.8238364458084106, iou: 0.7004438042640686
# epoch: 320, mb: 9, train cost: 0.0036, val cost: 0.0038,train acc: 0.9986, val acc: 0.9985,dice: 0.8196509480476379, iou: 0.6944140195846558
# epoch: 320, mb: 10, train cost: 0.0036, val cost: 0.0035,train acc: 0.9986, val acc: 0.9987,dice: 0.8384925723075867, iou: 0.7219003438949585
# epoch: 320, mb: 11, train cost: 0.0037, val cost: 0.0037,train acc: 0.9986, val acc: 0.9987,dice: 0.8333333134651184, iou: 0.7142857313156128
# epoch: 321, mb: 1, train cost: 0.0027, val cost: 0.0035,train acc: 0.9991, val acc: 0.9987,dice: 0.8410657048225403, iou: 0.7257233262062073
# epoch: 321, mb: 3, train cost: 0.0044, val cost: 0.0036,train acc: 0.9983, val acc: 0.9986,dice: 0.8277347087860107, iou: 0.7060984373092651
# epoch: 321, mb: 4, train cost: 0.0044, val cost: 0.0041,train acc: 0.9983, val acc: 0.9982,dice: 0.7969802021980286, iou: 0.6624830365180969
# epoch: 321, mb: 5, train cost: 0.0043, val cost: 0.0041,train acc: 0.9983, val acc: 0.9982,dice: 0.7990115284919739, iou: 0.6652949452400208
# epoch: 321, mb: 6, train cost: 0.0040, val cost: 0.0039,train acc: 0.9984, val acc: 0.9984,dice: 0.8154672384262085, iou: 0.6884294748306274
# epoch: 321, mb: 7, train cost: 0.0039, val cost: 0.0037,train acc: 0.9985, val acc: 0.9987,dice: 0.8291226625442505, iou: 0.7081208229064941
# epoch: 321, mb: 8, train cost: 0.0038, val cost: 0.0037,train acc: 0.9985, val acc: 0.9986,dice: 0.8283616304397583, iou: 0.707011342048645
# epoch: 321, mb: 9, train cost: 0.0038, val cost: 0.0038,train acc: 0.9985, val acc: 0.9985,dice: 0.8180211782455444, iou: 0.6920777559280396
# epoch: 321, mb: 10, train cost: 0.0037, val cost: 0.0044,train acc: 0.9986, val acc: 0.9981,dice: 0.7853618264198303, iou: 0.6465809345245361
# epoch: 321, mb: 11, train cost: 0.0036, val cost: 0.0046,train acc: 0.9986, val acc: 0.9979,dice: 0.7713773250579834, iou: 0.6278390884399414
# epoch: 322, mb: 1, train cost: 0.0061, val cost: 0.0045,train acc: 0.9970, val acc: 0.9980,dice: 0.777755081653595, iou: 0.6363332271575928
# epoch: 322, mb: 2, train cost: 0.0049, val cost: 0.0041,train acc: 0.9977, val acc: 0.9983,dice: 0.8020855784416199, iou: 0.6695683598518372
# epoch: 322, mb: 3, train cost: 0.0044, val cost: 0.0040,train acc: 0.9981, val acc: 0.9985,dice: 0.8074362874031067, iou: 0.6770592927932739
# epoch: 322, mb: 4, train cost: 0.0047, val cost: 0.0042,train acc: 0.9980, val acc: 0.9983,dice: 0.7716962695121765, iou: 0.6282617449760437
# epoch: 322, mb: 5, train cost: 0.0045, val cost: 0.0039,train acc: 0.9982, val acc: 0.9984,dice: 0.8107394576072693, iou: 0.6817172169685364
# epoch: 322, mb: 6, train cost: 0.0042, val cost: 0.0040,train acc: 0.9983, val acc: 0.9983,dice: 0.7989811301231384, iou: 0.6652527451515198
# epoch: 322, mb: 7, train cost: 0.0041, val cost: 0.0044,train acc: 0.9984, val acc: 0.9980,dice: 0.7807035446166992, iou: 0.6402901411056519
# epoch: 322, mb: 8, train cost: 0.0040, val cost: 0.0042,train acc: 0.9984, val acc: 0.9982,dice: 0.7992595434188843, iou: 0.6656389236450195
# epoch: 322, mb: 9, train cost: 0.0041, val cost: 0.0037,train acc: 0.9984, val acc: 0.9985,dice: 0.8225910663604736, iou: 0.6986451745033264
# epoch: 322, mb: 10, train cost: 0.0040, val cost: 0.0035,train acc: 0.9984, val acc: 0.9988,dice: 0.8441082239151001, iou: 0.7302657961845398
# epoch: 322, mb: 11, train cost: 0.0041, val cost: 0.0036,train acc: 0.9984, val acc: 0.9987,dice: 0.837480366230011, iou: 0.7204011082649231
# epoch: 323, mb: 1, train cost: 0.0032, val cost: 0.0037,train acc: 0.9989, val acc: 0.9986,dice: 0.8294727802276611, iou: 0.7086317539215088
# epoch: 323, mb: 2, train cost: 0.0032, val cost: 0.0036,train acc: 0.9988, val acc: 0.9986,dice: 0.8263238072395325, iou: 0.7040475010871887
# epoch: 323, mb: 3, train cost: 0.0030, val cost: 0.0038,train acc: 0.9989, val acc: 0.9986,dice: 0.8289241790771484, iou: 0.7078313231468201
# epoch: 323, mb: 4, train cost: 0.0030, val cost: 0.0036,train acc: 0.9988, val acc: 0.9988,dice: 0.8389830589294434, iou: 0.7226277589797974
# epoch: 323, mb: 5, train cost: 0.0036, val cost: 0.0036,train acc: 0.9986, val acc: 0.9988,dice: 0.844732403755188, iou: 0.731200635433197
# epoch: 323, mb: 6, train cost: 0.0036, val cost: 0.0036,train acc: 0.9986, val acc: 0.9988,dice: 0.8491988778114319, iou: 0.7379197478294373
# epoch: 323, mb: 7, train cost: 0.0035, val cost: 0.0036,train acc: 0.9986, val acc: 0.9987,dice: 0.8360949158668518, iou: 0.7183532118797302
# epoch: 323, mb: 8, train cost: 0.0035, val cost: 0.0036,train acc: 0.9987, val acc: 0.9987,dice: 0.8362494111061096, iou: 0.7185813188552856
# epoch: 323, mb: 9, train cost: 0.0035, val cost: 0.0036,train acc: 0.9987, val acc: 0.9987,dice: 0.8356870412826538, iou: 0.7177512645721436
# epoch: 323, mb: 10, train cost: 0.0037, val cost: 0.0035,train acc: 0.9986, val acc: 0.9986,dice: 0.8302136063575745, iou: 0.709713876247406
# epoch: 323, mb: 11, train cost: 0.0039, val cost: 0.0034,train acc: 0.9986, val acc: 0.9988,dice: 0.848302960395813, iou: 0.7365677356719971
# epoch: 324, mb: 1, train cost: 0.0027, val cost: 0.0035,train acc: 0.9989, val acc: 0.9988,dice: 0.8394632339477539, iou: 0.7233404517173767
# epoch: 324, mb: 2, train cost: 0.0038, val cost: 0.0035,train acc: 0.9984, val acc: 0.9988,dice: 0.8435184955596924, iou: 0.7293835282325745
# epoch: 324, mb: 3, train cost: 0.0039, val cost: 0.0035,train acc: 0.9984, val acc: 0.9986,dice: 0.8314360976219177, iou: 0.7115024328231812
# epoch: 324, mb: 4, train cost: 0.0037, val cost: 0.0036,train acc: 0.9985, val acc: 0.9986,dice: 0.828141987323761, iou: 0.7066914439201355
# epoch: 324, mb: 5, train cost: 0.0039, val cost: 0.0034,train acc: 0.9984, val acc: 0.9988,dice: 0.8432007431983948, iou: 0.7289084196090698
# epoch: 324, mb: 6, train cost: 0.0039, val cost: 0.0035,train acc: 0.9985, val acc: 0.9989,dice: 0.8520009517669678, iou: 0.7421616911888123
# epoch: 324, mb: 7, train cost: 0.0037, val cost: 0.0035,train acc: 0.9985, val acc: 0.9989,dice: 0.8491646647453308, iou: 0.7378681302070618
# epoch: 324, mb: 8, train cost: 0.0036, val cost: 0.0035,train acc: 0.9986, val acc: 0.9988,dice: 0.8417415618896484, iou: 0.7267302870750427
# epoch: 324, mb: 9, train cost: 0.0037, val cost: 0.0038,train acc: 0.9986, val acc: 0.9984,dice: 0.8147831559181213, iou: 0.6874549388885498
# epoch: 324, mb: 10, train cost: 0.0037, val cost: 0.0039,train acc: 0.9986, val acc: 0.9983,dice: 0.8063838481903076, iou: 0.6755805611610413
# epoch: 324, mb: 11, train cost: 0.0036, val cost: 0.0035,train acc: 0.9986, val acc: 0.9987,dice: 0.8394895792007446, iou: 0.7233796119689941
# epoch: 325, mb: 1, train cost: 0.0039, val cost: 0.0036,train acc: 0.9986, val acc: 0.9988,dice: 0.8463158011436462, iou: 0.7335766553878784
# epoch: 325, mb: 2, train cost: 0.0039, val cost: 0.0034,train acc: 0.9986, val acc: 0.9988,dice: 0.8490304946899414, iou: 0.7376654744148254
# epoch: 325, mb: 3, train cost: 0.0036, val cost: 0.0034,train acc: 0.9987, val acc: 0.9987,dice: 0.8381593823432922, iou: 0.7214065194129944
# epoch: 325, mb: 4, train cost: 0.0036, val cost: 0.0035,train acc: 0.9987, val acc: 0.9987,dice: 0.8363474011421204, iou: 0.7187260389328003
# epoch: 325, mb: 5, train cost: 0.0034, val cost: 0.0034,train acc: 0.9987, val acc: 0.9987,dice: 0.8405664563179016, iou: 0.7249802947044373
# epoch: 325, mb: 6, train cost: 0.0035, val cost: 0.0034,train acc: 0.9987, val acc: 0.9988,dice: 0.8415794372558594, iou: 0.7264887094497681
# epoch: 325, mb: 7, train cost: 0.0035, val cost: 0.0038,train acc: 0.9987, val acc: 0.9985,dice: 0.8169013857841492, iou: 0.6904761791229248
# epoch: 325, mb: 8, train cost: 0.0035, val cost: 0.0042,train acc: 0.9987, val acc: 0.9983,dice: 0.7971380352973938, iou: 0.6627011895179749
# epoch: 325, mb: 9, train cost: 0.0034, val cost: 0.0041,train acc: 0.9987, val acc: 0.9983,dice: 0.8023180961608887, iou: 0.6698924899101257
# epoch: 325, mb: 10, train cost: 0.0035, val cost: 0.0038,train acc: 0.9987, val acc: 0.9985,dice: 0.8207276463508606, iou: 0.6959611177444458
# epoch: 325, mb: 11, train cost: 0.0036, val cost: 0.0036,train acc: 0.9987, val acc: 0.9988,dice: 0.8401610255241394, iou: 0.7243772745132446
# epoch: 326, mb: 1, train cost: 0.0036, val cost: 0.0038,train acc: 0.9986, val acc: 0.9988,dice: 0.834942102432251, iou: 0.7166528701782227
# epoch: 326, mb: 2, train cost: 0.0035, val cost: 0.0034,train acc: 0.9987, val acc: 0.9987,dice: 0.8400646448135376, iou: 0.7242339849472046
# epoch: 326, mb: 3, train cost: 0.0036, val cost: 0.0037,train acc: 0.9987, val acc: 0.9985,dice: 0.8170285820960999, iou: 0.690657913684845
# epoch: 326, mb: 4, train cost: 0.0033, val cost: 0.0040,train acc: 0.9988, val acc: 0.9983,dice: 0.8031660318374634, iou: 0.6710755228996277
# epoch: 326, mb: 5, train cost: 0.0031, val cost: 0.0041,train acc: 0.9989, val acc: 0.9982,dice: 0.7962279915809631, iou: 0.6614441275596619
# epoch: 326, mb: 6, train cost: 0.0033, val cost: 0.0042,train acc: 0.9988, val acc: 0.9982,dice: 0.7941176295280457, iou: 0.6585366129875183
# epoch: 326, mb: 7, train cost: 0.0037, val cost: 0.0037,train acc: 0.9986, val acc: 0.9985,dice: 0.8228397965431213, iou: 0.699004054069519
# epoch: 326, mb: 8, train cost: 0.0036, val cost: 0.0035,train acc: 0.9986, val acc: 0.9988,dice: 0.8450035452842712, iou: 0.7316070795059204
# epoch: 326, mb: 9, train cost: 0.0037, val cost: 0.0051,train acc: 0.9986, val acc: 0.9978,dice: 0.6125786304473877, iou: 0.44152310490608215
# epoch: 326, mb: 10, train cost: 0.0040, val cost: 0.0042,train acc: 0.9983, val acc: 0.9983,dice: 0.8042238354682922, iou: 0.6725538969039917
# epoch: 326, mb: 11, train cost: 0.0040, val cost: 0.0085,train acc: 0.9983, val acc: 0.9958,dice: 0.6243523359298706, iou: 0.45386064052581787
# ...
# epoch: 739, mb: 10, train cost: 0.0020, val cost: 0.0061,train acc: 0.9993, val acc: 0.9984,dice: 0.7854151129722595, iou: 0.6466531157493591
# epoch: 739, mb: 11, train cost: 0.0020, val cost: 0.0059,train acc: 0.9993, val acc: 0.9984,dice: 0.785273015499115, iou: 0.6464605331420898
# epoch: 740, mb: 1, train cost: 0.0022, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7852398753166199, iou: 0.6464155316352844
# epoch: 740, mb: 2, train cost: 0.0022, val cost: 0.0052,train acc: 0.9993, val acc: 0.9984,dice: 0.7874599099159241, iou: 0.649429976940155
# epoch: 740, mb: 3, train cost: 0.0021, val cost: 0.0055,train acc: 0.9993, val acc: 0.9985,dice: 0.7907320857048035, iou: 0.6538931727409363
# epoch: 740, mb: 4, train cost: 0.0022, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7832098603248596, iou: 0.6436688303947449
# epoch: 740, mb: 5, train cost: 0.0021, val cost: 0.0058,train acc: 0.9993, val acc: 0.9984,dice: 0.7819031476974487, iou: 0.6419055461883545
# epoch: 740, mb: 6, train cost: 0.0021, val cost: 0.0055,train acc: 0.9993, val acc: 0.9984,dice: 0.7840825319290161, iou: 0.6448484659194946
# epoch: 740, mb: 7, train cost: 0.0020, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7893831133842468, iou: 0.6520503163337708
# epoch: 740, mb: 8, train cost: 0.0020, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.783271849155426, iou: 0.6437525153160095
# epoch: 740, mb: 9, train cost: 0.0020, val cost: 0.0055,train acc: 0.9993, val acc: 0.9984,dice: 0.7862444519996643, iou: 0.6477782130241394
# epoch: 740, mb: 10, train cost: 0.0020, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7806930541992188, iou: 0.6402760744094849
# epoch: 740, mb: 11, train cost: 0.0020, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7863121628761292, iou: 0.6478701829910278
# epoch: 741, mb: 1, train cost: 0.0021, val cost: 0.0055,train acc: 0.9993, val acc: 0.9984,dice: 0.7854151129722595, iou: 0.6466531157493591
# epoch: 741, mb: 2, train cost: 0.0021, val cost: 0.0054,train acc: 0.9992, val acc: 0.9984,dice: 0.7832306027412415, iou: 0.6436967849731445
# epoch: 741, mb: 3, train cost: 0.0021, val cost: 0.0053,train acc: 0.9993, val acc: 0.9985,dice: 0.7889410257339478, iou: 0.6514472365379333
# epoch: 741, mb: 4, train cost: 0.0021, val cost: 0.0047,train acc: 0.9993, val acc: 0.9985,dice: 0.789771318435669, iou: 0.6525802612304688
# epoch: 741, mb: 5, train cost: 0.0021, val cost: 0.0043,train acc: 0.9993, val acc: 0.9985,dice: 0.7994157671928406, iou: 0.6658556461334229
# epoch: 741, mb: 6, train cost: 0.0020, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7844488024711609, iou: 0.6453441381454468
# epoch: 741, mb: 7, train cost: 0.0020, val cost: 0.0047,train acc: 0.9993, val acc: 0.9984,dice: 0.7865554690361023, iou: 0.6482005715370178
# epoch: 741, mb: 8, train cost: 0.0020, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7822441458702087, iou: 0.6423653364181519
# epoch: 741, mb: 9, train cost: 0.0020, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7830999493598938, iou: 0.6435204148292542
# epoch: 741, mb: 10, train cost: 0.0020, val cost: 0.0062,train acc: 0.9993, val acc: 0.9984,dice: 0.784023642539978, iou: 0.6447688341140747
# epoch: 741, mb: 11, train cost: 0.0021, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.781411349773407, iou: 0.6412429213523865
# epoch: 742, mb: 1, train cost: 0.0018, val cost: 0.0052,train acc: 0.9994, val acc: 0.9984,dice: 0.7848350405693054, iou: 0.645867109298706
# epoch: 742, mb: 2, train cost: 0.0020, val cost: 0.0055,train acc: 0.9993, val acc: 0.9984,dice: 0.7866601347923279, iou: 0.6483427882194519
# epoch: 742, mb: 3, train cost: 0.0020, val cost: 0.0048,train acc: 0.9993, val acc: 0.9984,dice: 0.7878341674804688, iou: 0.6499392986297607
# epoch: 742, mb: 4, train cost: 0.0019, val cost: 0.0044,train acc: 0.9994, val acc: 0.9985,dice: 0.7983478903770447, iou: 0.6643752455711365
# epoch: 742, mb: 5, train cost: 0.0019, val cost: 0.0047,train acc: 0.9994, val acc: 0.9984,dice: 0.7889459729194641, iou: 0.651453971862793
# epoch: 742, mb: 6, train cost: 0.0019, val cost: 0.0045,train acc: 0.9994, val acc: 0.9985,dice: 0.8015583157539368, iou: 0.6688337922096252
# epoch: 742, mb: 7, train cost: 0.0019, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7836573719978333, iou: 0.644273579120636
# epoch: 742, mb: 8, train cost: 0.0020, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7866109013557434, iou: 0.6482758522033691
# epoch: 742, mb: 9, train cost: 0.0020, val cost: 0.0047,train acc: 0.9993, val acc: 0.9984,dice: 0.7892663478851318, iou: 0.6518909931182861
# epoch: 742, mb: 10, train cost: 0.0020, val cost: 0.0049,train acc: 0.9993, val acc: 0.9984,dice: 0.7872968912124634, iou: 0.6492083072662354
# epoch: 742, mb: 11, train cost: 0.0020, val cost: 0.0065,train acc: 0.9993, val acc: 0.9984,dice: 0.7862407565116882, iou: 0.647773265838623
# epoch: 743, mb: 1, train cost: 0.0022, val cost: 0.0052,train acc: 0.9993, val acc: 0.9984,dice: 0.7848536968231201, iou: 0.645892322063446
# epoch: 743, mb: 2, train cost: 0.0021, val cost: 0.0057,train acc: 0.9993, val acc: 0.9984,dice: 0.7846418619155884, iou: 0.6456055045127869
# epoch: 743, mb: 3, train cost: 0.0021, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7826513051986694, iou: 0.6429146528244019
# epoch: 743, mb: 4, train cost: 0.0020, val cost: 0.0057,train acc: 0.9993, val acc: 0.9984,dice: 0.7834645509719849, iou: 0.6440129280090332
# epoch: 743, mb: 5, train cost: 0.0021, val cost: 0.0058,train acc: 0.9993, val acc: 0.9984,dice: 0.7870461344718933, iou: 0.6488673090934753
# epoch: 743, mb: 6, train cost: 0.0020, val cost: 0.0046,train acc: 0.9993, val acc: 0.9984,dice: 0.7889953255653381, iou: 0.6515213251113892
# epoch: 743, mb: 7, train cost: 0.0020, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7827585935592651, iou: 0.643059492111206
# epoch: 743, mb: 8, train cost: 0.0020, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7826301455497742, iou: 0.6428861021995544
# epoch: 743, mb: 9, train cost: 0.0020, val cost: 0.0046,train acc: 0.9993, val acc: 0.9984,dice: 0.7869735360145569, iou: 0.6487686634063721
# epoch: 743, mb: 10, train cost: 0.0020, val cost: 0.0065,train acc: 0.9993, val acc: 0.9984,dice: 0.7850329875946045, iou: 0.6461352705955505
# epoch: 743, mb: 11, train cost: 0.0020, val cost: 0.0047,train acc: 0.9993, val acc: 0.9985,dice: 0.7905604839324951, iou: 0.6536585092544556
# epoch: 744, mb: 1, train cost: 0.0023, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7856616973876953, iou: 0.6469874382019043
# epoch: 744, mb: 2, train cost: 0.0023, val cost: 0.0060,train acc: 0.9992, val acc: 0.9984,dice: 0.7808961272239685, iou: 0.6405493021011353
# epoch: 744, mb: 3, train cost: 0.0021, val cost: 0.0055,train acc: 0.9993, val acc: 0.9984,dice: 0.7817509174346924, iou: 0.6417003870010376
# epoch: 744, mb: 4, train cost: 0.0020, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7875520586967468, iou: 0.6495553851127625
# epoch: 744, mb: 5, train cost: 0.0020, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.782544732093811, iou: 0.6427708268165588
# epoch: 744, mb: 6, train cost: 0.0021, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7839171290397644, iou: 0.6446247696876526
# epoch: 744, mb: 7, train cost: 0.0021, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7812192440032959, iou: 0.640984296798706
# epoch: 744, mb: 8, train cost: 0.0021, val cost: 0.0045,train acc: 0.9993, val acc: 0.9985,dice: 0.8012679815292358, iou: 0.6684296131134033
# epoch: 744, mb: 9, train cost: 0.0021, val cost: 0.0051,train acc: 0.9993, val acc: 0.9984,dice: 0.78091961145401, iou: 0.6405808925628662
# epoch: 744, mb: 10, train cost: 0.0020, val cost: 0.0046,train acc: 0.9993, val acc: 0.9985,dice: 0.8001942038536072, iou: 0.666936457157135
# epoch: 744, mb: 11, train cost: 0.0020, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7835710644721985, iou: 0.6441568732261658
# epoch: 745, mb: 1, train cost: 0.0019, val cost: 0.0053,train acc: 0.9994, val acc: 0.9984,dice: 0.7857142686843872, iou: 0.6470588445663452
# epoch: 745, mb: 2, train cost: 0.0019, val cost: 0.0048,train acc: 0.9993, val acc: 0.9984,dice: 0.786788284778595, iou: 0.648516833782196
# epoch: 745, mb: 3, train cost: 0.0020, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7865389585494995, iou: 0.6481781601905823
# epoch: 745, mb: 4, train cost: 0.0020, val cost: 0.0046,train acc: 0.9993, val acc: 0.9985,dice: 0.7905951738357544, iou: 0.6537059545516968
# epoch: 745, mb: 5, train cost: 0.0019, val cost: 0.0058,train acc: 0.9994, val acc: 0.9984,dice: 0.7834597229957581, iou: 0.6440064311027527
# epoch: 745, mb: 6, train cost: 0.0019, val cost: 0.0053,train acc: 0.9994, val acc: 0.9984,dice: 0.7835710644721985, iou: 0.6441568732261658
# epoch: 745, mb: 7, train cost: 0.0019, val cost: 0.0057,train acc: 0.9994, val acc: 0.9984,dice: 0.7837374210357666, iou: 0.6443818211555481
# epoch: 745, mb: 8, train cost: 0.0020, val cost: 0.0052,train acc: 0.9993, val acc: 0.9984,dice: 0.7843233942985535, iou: 0.6451743841171265
# epoch: 745, mb: 9, train cost: 0.0020, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7871505618095398, iou: 0.6490092873573303
# epoch: 745, mb: 10, train cost: 0.0020, val cost: 0.0064,train acc: 0.9993, val acc: 0.9984,dice: 0.7820544242858887, iou: 0.6421095132827759
# epoch: 745, mb: 11, train cost: 0.0020, val cost: 0.0052,train acc: 0.9993, val acc: 0.9984,dice: 0.7843619585037231, iou: 0.6452265381813049
# epoch: 746, mb: 1, train cost: 0.0019, val cost: 0.0044,train acc: 0.9993, val acc: 0.9985,dice: 0.8017471432685852, iou: 0.669096827507019
# epoch: 746, mb: 2, train cost: 0.0021, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7830142378807068, iou: 0.6434046030044556
# epoch: 746, mb: 3, train cost: 0.0021, val cost: 0.0066,train acc: 0.9993, val acc: 0.9984,dice: 0.7846983671188354, iou: 0.6456819772720337
# epoch: 746, mb: 4, train cost: 0.0021, val cost: 0.0047,train acc: 0.9993, val acc: 0.9984,dice: 0.7817057967185974, iou: 0.6416395902633667
# epoch: 746, mb: 5, train cost: 0.0021, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7848163843154907, iou: 0.6458417773246765
# epoch: 746, mb: 6, train cost: 0.0021, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7851017117500305, iou: 0.6462283134460449
# epoch: 746, mb: 7, train cost: 0.0021, val cost: 0.0056,train acc: 0.9993, val acc: 0.9984,dice: 0.7823312878608704, iou: 0.6424828767776489
# epoch: 746, mb: 8, train cost: 0.0020, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7840825319290161, iou: 0.6448484659194946
# epoch: 746, mb: 9, train cost: 0.0020, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.782459557056427, iou: 0.6426559090614319
# epoch: 746, mb: 10, train cost: 0.0020, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7833784222602844, iou: 0.6438965201377869
# epoch: 746, mb: 11, train cost: 0.0020, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7806435823440552, iou: 0.6402094960212708
# epoch: 747, mb: 1, train cost: 0.0022, val cost: 0.0047,train acc: 0.9992, val acc: 0.9984,dice: 0.7869822382926941, iou: 0.6487804651260376
# epoch: 747, mb: 2, train cost: 0.0020, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7885040640830994, iou: 0.6508516073226929
# epoch: 747, mb: 3, train cost: 0.0020, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7834645509719849, iou: 0.6440129280090332
# epoch: 747, mb: 4, train cost: 0.0021, val cost: 0.0047,train acc: 0.9993, val acc: 0.9984,dice: 0.7826515436172485, iou: 0.6429149508476257
# epoch: 747, mb: 5, train cost: 0.0021, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7828220725059509, iou: 0.6431451439857483
# epoch: 747, mb: 6, train cost: 0.0020, val cost: 0.0060,train acc: 0.9993, val acc: 0.9984,dice: 0.7850146889686584, iou: 0.6461104154586792
# epoch: 747, mb: 7, train cost: 0.0020, val cost: 0.0046,train acc: 0.9993, val acc: 0.9984,dice: 0.7881481647491455, iou: 0.6503667235374451
# epoch: 747, mb: 8, train cost: 0.0019, val cost: 0.0047,train acc: 0.9993, val acc: 0.9984,dice: 0.7861186265945435, iou: 0.6476074457168579
# epoch: 747, mb: 9, train cost: 0.0020, val cost: 0.0057,train acc: 0.9993, val acc: 0.9984,dice: 0.7852579951286316, iou: 0.6464401483535767
# epoch: 747, mb: 10, train cost: 0.0020, val cost: 0.0047,train acc: 0.9993, val acc: 0.9984,dice: 0.7870142459869385, iou: 0.6488240361213684
# epoch: 747, mb: 11, train cost: 0.0020, val cost: 0.0050,train acc: 0.9993, val acc: 0.9984,dice: 0.7838037014007568, iou: 0.6444713473320007
# epoch: 748, mb: 1, train cost: 0.0019, val cost: 0.0055,train acc: 0.9994, val acc: 0.9984,dice: 0.7838503122329712, iou: 0.6445344090461731
# epoch: 748, mb: 2, train cost: 0.0019, val cost: 0.0057,train acc: 0.9993, val acc: 0.9984,dice: 0.7825228571891785, iou: 0.6427412629127502
# epoch: 748, mb: 3, train cost: 0.0020, val cost: 0.0059,train acc: 0.9993, val acc: 0.9984,dice: 0.7845167517662048, iou: 0.6454361081123352
# epoch: 748, mb: 4, train cost: 0.0020, val cost: 0.0060,train acc: 0.9993, val acc: 0.9984,dice: 0.7851524353027344, iou: 0.646297037601471
# epoch: 748, mb: 5, train cost: 0.0021, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7873125076293945, iou: 0.6492295265197754
# epoch: 748, mb: 6, train cost: 0.0021, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7849963307380676, iou: 0.6460855603218079
# epoch: 748, mb: 7, train cost: 0.0020, val cost: 0.0048,train acc: 0.9993, val acc: 0.9984,dice: 0.7882960438728333, iou: 0.6505681872367859
# epoch: 748, mb: 8, train cost: 0.0020, val cost: 0.0057,train acc: 0.9993, val acc: 0.9984,dice: 0.7831444144248962, iou: 0.6435803771018982
# epoch: 748, mb: 9, train cost: 0.0020, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7849409580230713, iou: 0.6460105180740356
# epoch: 748, mb: 10, train cost: 0.0020, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7833784222602844, iou: 0.6438965201377869
# epoch: 748, mb: 11, train cost: 0.0020, val cost: 0.0055,train acc: 0.9993, val acc: 0.9984,dice: 0.784023642539978, iou: 0.6447688341140747
# epoch: 749, mb: 1, train cost: 0.0018, val cost: 0.0057,train acc: 0.9994, val acc: 0.9984,dice: 0.783337414264679, iou: 0.6438411474227905
# epoch: 749, mb: 2, train cost: 0.0019, val cost: 0.0047,train acc: 0.9993, val acc: 0.9984,dice: 0.7830999493598938, iou: 0.6435204148292542
# epoch: 749, mb: 3, train cost: 0.0020, val cost: 0.0048,train acc: 0.9993, val acc: 0.9984,dice: 0.7862444519996643, iou: 0.6477782130241394
# epoch: 749, mb: 4, train cost: 0.0021, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7837175130844116, iou: 0.6443548202514648
# epoch: 749, mb: 5, train cost: 0.0021, val cost: 0.0054,train acc: 0.9993, val acc: 0.9984,dice: 0.7820733785629272, iou: 0.6421350836753845
# epoch: 749, mb: 6, train cost: 0.0021, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7821612358093262, iou: 0.6422535181045532
# epoch: 749, mb: 7, train cost: 0.0021, val cost: 0.0053,train acc: 0.9993, val acc: 0.9984,dice: 0.7844870090484619, iou: 0.645395815372467
# epoch: 749, mb: 8, train cost: 0.0021, val cost: 0.0056,train acc: 0.9993, val acc: 0.9984,dice: 0.7821174263954163, iou: 0.6421944499015808
# epoch: 749, mb: 9, train cost: 0.0020, val cost: 0.0048,train acc: 0.9993, val acc: 0.9984,dice: 0.7843427062034607, iou: 0.6452004909515381
# epoch: 749, mb: 10, train cost: 0.0020, val cost: 0.0062,train acc: 0.9993, val acc: 0.9984,dice: 0.7859252095222473, iou: 0.6473449468612671
# epoch: 749, mb: 11, train cost: 0.0020, val cost: 0.0047,train acc: 0.9993, val acc: 0.9984,dice: 0.787714958190918, iou: 0.6497770547866821
# Confusion Matrix:
# [[1577, 294], [578, 549487]]
# Loss: 0.0053
# Accuracy: 0.0029
# Recall: 0.7318
# Precision: 0.8429
# F1 Score: 0.7834

# %%
torch.save(model.state_dict(), 'model_trainedS.pth')

# %%
print("Confusion Matrix:")
print(confusion_matrix)
tp, fp = confusion_matrix[0]
fn, tn = confusion_matrix[1]

# Crear una lista con los nombres de las clases
class_names = ["True Positive", "False Positive", "False Negative", "True Negative"]

# Crear una figura y un eje para el gráfico de barras
fig, ax = plt.subplots()

# Crear el gráfico de barras
ax.bar(class_names, [tp, fp, fn, tn], color=["green", "red", "red", "green"])

# Configurar las etiquetas de los ejes y el título del gráfico
ax.set_xlabel("Class")
ax.set_ylabel("Number of samples")
ax.set_title("Confusion Matrix")

# Mostrar el gráfico
plt.show()
# Out:
# Confusion Matrix:
# [[1577, 294], [578, 549487]]

# %%
####CURVAS ROC
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

cm = confusion_matrix
print(cm)
cm = np.array(cm)

y_true = np.concatenate([np.zeros(cm[0, 0] + cm[0, 1]), np.ones(cm[1, 0] + cm[1, 1])])
y_scores = np.concatenate([np.zeros(cm[0, 0]), np.ones(cm[1, 0]), np.zeros(cm[0, 1]), np.ones(cm[1, 1])])

# Calcular la tasa de verdaderos positivos (TPR) y la tasa de falsos positivos (FPR) para diferentes umbrales de clasificación
fpr, tpr, thresholds = roc_curve(y_true, y_scores)

# Calcular el área bajo la curva ROC (AUC)
roc_auc = auc(fpr, tpr)

# Graficar la curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='Curva ROC (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC')
plt.legend(loc="lower right")
plt.show()
# Out:
# [[1577, 294], [578, 549487]]

# %%
fprs, tprs = lift(model, val_loader)
import matplotlib.pyplot as plt
plt.plot(fprs, tprs)
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.show()

# %%
imgs_val, masks_val = next(iter(val_loader))
imgs_val = imgs_val.to(device, dtype=torch.float32)
imgs_val = torch.narrow(imgs_val, 1, 0, 3)
model = model.to(device)
with torch.no_grad():
    scores = model(imgs_val)
    preds = torch.argmax(scores, dim=1).float()

imgs_val = imgs_val.cpu()
preds = preds.cpu()
print(preds.shape)
plot_mini_batch(imgs_val, preds.unsqueeze(1))
# Out:
# torch.Size([4, 224, 224])

# %%
###PRUEBA // TESTEO
test_set = Person_Dataset(TEST_PATH, img_transforms=transform_data)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=True)

# %%
imgs_test = next(iter(test_loader))
imgs_test = imgs_test.to(device, dtype=torch.float32)
imgs_test = torch.narrow(imgs_test, 1, 0, 3)
model = model.to(device)
with torch.no_grad():
    scores = model(imgs_test)
    preds = torch.argmax(scores, dim=1).float()

imgs_test = imgs_test.cpu()
preds = preds.cpu()
print(preds.shape)
plot_mini_batch(imgs_test, preds.unsqueeze(1))

# %%
###PARA IMPRIMIR TODO EL DATASET
model = model.to(device)
with torch.no_grad():
    for batch in test_loader:
        imgs_test = batch.to(device, dtype=torch.float32)
        print(imgs_test.shape)
        imgs_test = torch.narrow(imgs_test, 1, 0, 3)
        
        scores = model(imgs_test)
        preds = torch.argmax(scores, dim=1).float()

        imgs_test = imgs_test.cpu()
        preds = preds.cpu()
        plot_mini_batch(imgs_test, preds.unsqueeze(1))
# Out:
# torch.Size([4, 4, 224, 224])
# torch.Size([4, 4, 224, 224])
# torch.Size([4, 4, 224, 224])
# torch.Size([3, 4, 224, 224])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-29abd9c7f173> in <module>
#      12         imgs_test = imgs_test.cpu()
#      13         preds = preds.cpu()
# ---> 14         plot_mini_batch(imgs_test, preds.unsqueeze(1))
#
# <ipython-input-14-7ee0a7218a14> in plot_mini_batch(imgs, masks)
#       4     for i in range(BATCH_SIZE):
#       5         plt.subplot(4, 8, i+1)
# ----> 6         img=imgs[i,...].permute(1,2,0).numpy()
#       7         mask = masks[i, ...].permute(1,2,0).numpy()
#       8         plt.imshow(img)
#
# IndexError: index 3 is out of bounds for dimension 0 with size 3

# %%
###PRUEBA // TESTEO
test_set2 = Person_Dataset(TEST2_PATH, img_transforms=transform_data)
test_loader2 = DataLoader(test_set2, batch_size=BATCH_SIZE, shuffle=True)
model = model.to(device)
with torch.no_grad():
    for batch in test_loader2:
        imgs_test = batch.to(device, dtype=torch.float32)
        print(imgs_test.shape)
        imgs_test = torch.narrow(imgs_test, 1, 0, 3)
        
        scores = model(imgs_test)
        preds = torch.argmax(scores, dim=1).float()

        imgs_test = imgs_test.cpu()
        preds = preds.cpu()
        plot_mini_batch(imgs_test, preds.unsqueeze(1))
# Out:
# torch.Size([1, 3, 224, 224])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-d163c9310c64> in <module>
#      14         imgs_test = imgs_test.cpu()
#      15         preds = preds.cpu()
# ---> 16         plot_mini_batch(imgs_test, preds.unsqueeze(1))
#
# <ipython-input-14-7ee0a7218a14> in plot_mini_batch(imgs, masks)
#       4     for i in range(BATCH_SIZE):
#       5         plt.subplot(4, 8, i+1)
# ----> 6         img=imgs[i,...].permute(1,2,0).numpy()
#       7         mask = masks[i, ...].permute(1,2,0).numpy()
#       8         plt.imshow(img)
#
# IndexError: index 1 is out of bounds for dimension 0 with size 1
